# %%
import pandas as pd                                     # type: ignore
import numpy as np                                      # type: ignore
import warnings                                         # type: ignore
from sklearn.model_selection import train_test_split    # type: ignore
from sklearn.decomposition import PCA                   # type: ignore
from sklearn.preprocessing import StandardScaler, MinMaxScaler# type: ignore
from sklearn.model_selection import GridSearchCV, KFold # type: ignore
from sklearn.metrics import f1_score, accuracy_score, precision_score, recall_score, roc_auc_score, roc_curve, precision_recall_curve# type: ignore
import tensorflow as tf                                 # type: ignore
from tensorflow import keras                            # type: ignore
from keras.layers import Dense, Dropout                 # type: ignore
from keras.optimizers import Adam, SGD                  # type: ignore
from keras.callbacks import EarlyStopping               # type: ignore
from kerastuner.tuners import Hyperband                 # type: ignore
from tensorboard.plugins.hparams import api as hp       # type: ignore
import matplotlib.pyplot as plt                         # type: ignore
from imblearn.over_sampling import RandomOverSampler, SMOTE# type: ignore
from imblearn.under_sampling import TomekLinks          # type: ignore
from itertools import combinations_with_replacement
warnings.filterwarnings(action='ignore')

tf.config.set_visible_devices([], 'GPU')
# Out:
# C:\Users\Hi\AppData\Local\Temp\ipykernel_21976\3860009895.py:14: DeprecationWarning: `import kerastuner` is deprecated, please use `import keras_tuner`.
#   from kerastuner.tuners import Hyperband                 # type: ignore

# %%
# GPU 설정
physical_devices = tf.config.list_physical_devices('GPU')
if physical_devices:
    tf.config.experimental.set_memory_growth(physical_devices[0], True)
    print(physical_devices[0])
# Out:
# PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')

# %%
class DNNModel:
    def __init__(self) -> None:
        self.model = None
        self.df = None
        self.x_train = None
        self.y_train = None
        self.input_dim = 0
        self.model_name = ""

    def load_file(self, file_path:str)->None:
        self.df = pd.read_csv(file_path)
        x_train = self.df.drop(columns=['loan_status', 'Unnamed: 0'])
        # x_train = self.df.drop(columns=['loan_status'])
        
        y_train = self.df['loan_status']
        nan_indices = np.isnan(x_train).any(axis=1)
        self.x_train = x_train[~nan_indices]
        self.y_train = y_train[~nan_indices]
    
    def __get_n_components_from_pca(self, scaled_data:pd.DataFrame, threshold:float) -> int:
        pca = PCA()
        pca.fit(scaled_data)
        explained_variance = pca.explained_variance_ratio_
        cumulative_explained_variance = np.cumsum(explained_variance)
        n_components = np.argmax(cumulative_explained_variance >= threshold) + 1
        return n_components
    
    def scaling_data(
            self, 
            scaler:MinMaxScaler|StandardScaler=StandardScaler, 
            threshold:float=0.95, 
            over_sampler:SMOTE|RandomOverSampler=None, 
            under_sampler:TomekLinks=None)->None:
        x_scaled = scaler().fit_transform(self.x_train)
        self.input_dim = self.__get_n_components_from_pca(x_scaled, threshold=threshold)
        self.model_name+=(f'scaler({scaler.__name__})_pca({(int(threshold*100))})_input({str(self.input_dim)})')
        self.x_train = PCA(n_components=self.input_dim).fit_transform(x_scaled).astype('float32')
        if over_sampler!=None:
            os = over_sampler(random_state=30)
            self.x_train, self.y_train = os.fit_resample(self.x_train,self.y_train)
            self.model_name+=f'_sampler({os.__class__.__name__})'
            print(f"====Data set resampled(oversampled)_{os.__class__.__name__}")
        elif under_sampler!=None:
            us = under_sampler(random_state=30, sampling_strategy='majority')
            self.x_train, self.y_train = us.fit_resample(self.x_train, self.y_train)
            self.model_name+=f'_sampler({us.__class__.__name__})'
            print(f"====Data set resampled(undersampled)_{us.__class__.__name__}")
        print(f"==label ratio")
        print(f"True Label:\t{np.sum(self.y_train==1)/len(self.y_train)}")
        print(f"False Label:\t{np.sum(self.y_train==0)/len(self.y_train)}")
        self.x_train, self.x_validation, self.y_train, self.y_validation = train_test_split(self.x_train, self.y_train, test_size=0.2, stratify=self.y_train, random_state=30)
    
    def __build_model(self, num_layers:int, num_nodes:int, loss:str, num_nodes_per_each_layers:list[int]=None)->keras.Sequential:
        # Define and compile the model
        model = keras.Sequential()
        model.add(Dense(num_nodes, input_dim=self.input_dim, activation='relu'))
        for layer_index in range(num_layers):
            if num_nodes_per_each_layers:
                model.add(Dense(num_nodes_per_each_layers[layer_index], activation='relu'))
            else:
                model.add(Dense(num_nodes, activation='relu'))
            model.add(Dropout(0.2))
        model.add(Dense(1, activation='sigmoid'))
        model.compile(optimizer='Adam', loss=loss, metrics=["accuracy"])
        return model
    
    def searching_best_param_grid(
            self, 
            grid_params:dict,
            params:dict={'min_delta':0.001, "n_splits":5},
            scoring='accuracy'
            ):
        kfold = KFold(random_state=30,
                n_splits=params['n_splits'],
                shuffle=True
                )
        model = tf.keras.wrappers.scikit_learn.KerasClassifier(build_fn=self.__build_model)
        # GridSearchCV 생성
        grid_search = GridSearchCV(estimator = model,
                                param_grid = grid_params,
                                cv = kfold,
                                scoring=scoring)
        early_stopping = EarlyStopping(monitor='loss',min_delta=params['min_delta'])
        # GridSearchCV fit 시작
        grid_search.fit(self.x_train, self.y_train, callbacks=[early_stopping])
        # 최적의 param
        print(f"Best params: {grid_search.best_params_}")
        # 최적의 param일 경우 최적의 accuracy
        print(f"Best average accuracy: {grid_search.best_score_}")
        return grid_search.best_params_, grid_search.best_score_

    def build_model_with_best_params(
            self, 
            best_params:dict, 
            params:dict={'min_delta':0.001, "n_splits":5}, 
            threshold:float=0.5)->dict:
        valid_accs, valid_f1s, valid_recalls, valid_precisions = [], [], [], []
        result_dict = {
                       'average validation accuracy':0,
                       'average validation recall':0,
                       'average validation precision':0,
                       'average validation f1':0,
                       'validation accuracy':0,
                       'validation recall':0,
                       'validation precision':0,
                       'validation f1':0,
                       }
        y_train_reshaped = np.reshape(self.y_train,(-1))
        model = self.__build_model(best_params['num_layers'], best_params['num_nodes'], best_params['loss'])
        kf = KFold(n_splits=params['n_splits'], shuffle=True, random_state=30)
        early_stopping = EarlyStopping(monitor='loss',min_delta=params['min_delta'])
        for train_index, val_index in kf.split(self.x_train, y_train_reshaped):
            X_train_fold, X_val_fold = self.x_train[train_index], self.x_train[val_index]
            Y_train_fold, Y_val_fold = y_train_reshaped[train_index], y_train_reshaped[val_index]
            # 모델 학습
            model.fit(X_train_fold, 
                    Y_train_fold, 
                    batch_size=best_params['batch_size'], 
                    epochs=best_params['epochs'], 
                    verbose=1,
                    callbacks=[early_stopping])
            # 모델 validation
            valid_loss, valid_acc= model.evaluate(X_val_fold, Y_val_fold)
            pred = model.predict(X_val_fold).flatten()
            pred = np.where(pred >= threshold, 1 , 0)
            valid_accs.append(valid_acc)
            valid_f1s.append(f1_score(Y_val_fold, pred))
            valid_precisions.append(precision_score(Y_val_fold, pred))
            valid_recalls.append(recall_score(Y_val_fold, pred))
        result_dict['average validation accuracy'] = np.mean(valid_accs)
        result_dict['average validation recall'] = np.mean(valid_recalls)
        result_dict['average validation precision'] = np.mean(valid_precisions)
        result_dict['average validation f1'] = np.mean(valid_f1s)
        print("###################################")
        print("avg Validation accuracy:", result_dict['average validation accuracy'])
        print("avg Validation recall:", result_dict['average validation recall'])
        print("avg Validation precision:", result_dict['average validation precision'])
        print("avg Validation F1-score:", result_dict['average validation f1'])

        valid_pred = model.predict(self.x_validation).flatten()
        valid_pred = np.where(valid_pred>=threshold, 1, 0)

        result_dict['validation accuracy'] = accuracy_score(Y_val_fold, pred)
        result_dict['validation f1'] = (f1_score(Y_val_fold, pred))
        result_dict['validation precision'] = (precision_score(Y_val_fold, pred))
        result_dict['validation recall'] = (recall_score(Y_val_fold, pred))
        print("###################################")
        print("Validation accuracy:", result_dict['validation accuracy'])
        print("Validation recall:", result_dict['validation recall'])
        print("Validation precision:", result_dict['validation precision'])
        print("Validation F1-score:", result_dict['validation f1'])
        self.model = model
        return result_dict
    
    def save_model(self, file_path:str="dnn_models/0425/dnn_")->None:
        self.model.save(file_path+self.model_name+'.h5')
 
    def load_model(self, model_file_path:str="dnn_models/0425/dnn_"):
        self.model = tf.keras.models.load_model(model_file_path)

    def get_input_dim(self)->int:
        return self.input_dim

    def get_model(self)->keras.Sequential:
        return self.model

    def get_model_name(self)->str:
        return self.model_name

    def get_roc_auc_score(self, save:bool=True)->float:
        valid_pred = self.model.predict(self.x_validation).flatten()
        fprs, tprs, thresholds = roc_curve(self.y_validation, valid_pred)
        plt.figure(figsize=(10, 5))
        plt.plot(fprs, tprs, label='ROC')
        plt.xlabel("FPR(Fall-Out)")
        plt.ylabel("TPR(Recall):재현률")
        plt.legend()
        plt.show()
        if save:
            plt.savefig(f'plots/{self.model_name}.png')
        return roc_auc_score(self.y_validation, valid_pred)
    
    def draw_precision_recall_curve_plot(self, min_delta:float=0.01, save:bool=True)->float:
        valid_pred = self.model.predict(self.x_validation).flatten()
        precisions, recalls, thresholds = precision_recall_curve(self.y_validation, valid_pred)
        # y축인 precisions와 recalls의 갯수 = threshold 갯수 + 1 이어서 x,y 갯수를 동일하게 맞춰줌
        thres_boundary = thresholds.shape[0]
        plt.plot(thresholds, precisions[:thres_boundary], "r", label="precision")
        plt.plot(thresholds, recalls[:thres_boundary], label="recall")

        # x축 스케일 0.1 단위로 조정
        start, end = plt.xlim()
        plt.xticks( np.round( np.arange(start, end, 0.1), 2))
        # 라벨링
        plt.xlabel("Threshold value"), plt.ylabel("Precision and Recall value")
        plt.legend()
        plt.show()
        if save:
            plt.savefig(f'plots/{self.model_name}_precision&recall.png')
        min_delta_index = None
        for i in range(len(precisions)):
            delta = abs(precisions[i] - recalls[i])
            if delta <= min_delta:
                min_delta_index = i
                break
        return recalls[min_delta_index]
    
    def get_y_train(self)->np.ndarray:
        return self.y_train
    
    def get_y_validation(self)->np.ndarray:
        return self.y_validation

# %%
dnn_model = DNNModel()
dnn_model.load_file('data/final_train.csv')
dnn_model.scaling_data(StandardScaler, threshold=0.95, over_sampler=SMOTE)
input_dim = dnn_model.get_input_dim()
grid_params = {
    'batch_size': [100, 200, 400], 
    'epochs': [5], 
    'loss': ['binary_crossentropy'], 
    'num_layers': [3], 
    'num_nodes': [input_dim//2, input_dim*3//4, input_dim]}
best_params, _ = dnn_model.searching_best_param_grid(grid_params=grid_params)
# best_params = {'batch_size': 10000, 'epochs': 5, 'loss': 'binary_crossentropy', 'num_layers': 3, 'num_nodes': input_dim*2//3}
metric_result_dictionary = dnn_model.build_model_with_best_params(best_params=best_params, threshold=0.5)
print(f'AUC: {dnn_model.get_roc_auc_score()}')
model_name = dnn_model.get_model_name()
print(f'approximate optimal recall: {dnn_model.draw_precision_recall_curve_plot(min_delta=0.0001)}')
dnn_model.save_model()
# Out:
# ====Data set resampled(oversampled)_SMOTE
# ==label ratio
# True Label:	0.5
# False Label:	0.5
# Epoch 1/5
# 11559/11559 [==============================] - 13s 1ms/step - loss: 0.6326 - accuracy: 0.6442
# Epoch 2/5
# 11559/11559 [==============================] - 11s 989us/step - loss: 0.6260 - accuracy: 0.6511
# 9030/9030 [==============================] - 5s 564us/step
# Epoch 1/5
# 11559/11559 [==============================] - 12s 993us/step - loss: 0.6316 - accuracy: 0.6465
# Epoch 2/5
# 11559/11559 [==============================] - 11s 989us/step - loss: 0.6253 - accuracy: 0.6527
# 9030/9030 [==============================] - 5s 580us/step
# Epoch 1/5
# 11559/11559 [==============================] - 12s 975us/step - loss: 0.6333 - accuracy: 0.6443
# Epoch 2/5
# 11559/11559 [==============================] - 11s 970us/step - loss: 0.6266 - accuracy: 0.6507
# 9030/9030 [==============================] - 5s 581us/step
# Epoch 1/5
# 11559/11559 [==============================] - 12s 996us/step - loss: 0.6347 - accuracy: 0.6414
# Epoch 2/5
# 11559/11559 [==============================] - 12s 1ms/step - loss: 0.6269 - accuracy: 0.6515
# 9030/9030 [==============================] - 5s 573us/step
# Epoch 1/5
# 11559/11559 [==============================] - 12s 992us/step - loss: 0.6335 - accuracy: 0.6433
# Epoch 2/5
# 11559/11559 [==============================] - 11s 991us/step - loss: 0.6260 - accuracy: 0.6517
# 9030/9030 [==============================] - 5s 578us/step
# Epoch 1/5
# 11559/11559 [==============================] - 12s 1ms/step - loss: 0.6291 - accuracy: 0.6477
# Epoch 2/5
# 11559/11559 [==============================] - 12s 1ms/step - loss: 0.6232 - accuracy: 0.6536
# 9030/9030 [==============================] - 5s 582us/step
# Epoch 1/5
# 11559/11559 [==============================] - 12s 1ms/step - loss: 0.6301 - accuracy: 0.6466
# Epoch 2/5
# 11559/11559 [==============================] - 12s 1ms/step - loss: 0.6233 - accuracy: 0.6533
# 9030/9030 [==============================] - 6s 614us/step
# Epoch 1/5
# 11559/11559 [==============================] - 13s 1ms/step - loss: 0.6285 - accuracy: 0.6484
# Epoch 2/5
# 11559/11559 [==============================] - 12s 1ms/step - loss: 0.6230 - accuracy: 0.6541
# 9030/9030 [==============================] - 5s 588us/step
# Epoch 1/5
# 11559/11559 [==============================] - 13s 1ms/step - loss: 0.6302 - accuracy: 0.6462
# Epoch 2/5
# 11559/11559 [==============================] - 12s 1ms/step - loss: 0.6238 - accuracy: 0.6529
# 9030/9030 [==============================] - 5s 598us/step
# Epoch 1/5
# 11559/11559 [==============================] - 13s 1ms/step - loss: 0.6295 - accuracy: 0.6475
# Epoch 2/5
# 11559/11559 [==============================] - 12s 1ms/step - loss: 0.6238 - accuracy: 0.6534
# 9030/9030 [==============================] - 5s 589us/step
# Epoch 1/5
# 11559/11559 [==============================] - 14s 1ms/step - loss: 0.6283 - accuracy: 0.6485
# Epoch 2/5
# 11559/11559 [==============================] - 13s 1ms/step - loss: 0.6219 - accuracy: 0.6544
# 9030/9030 [==============================] - 5s 599us/step
# Epoch 1/5
# 11559/11559 [==============================] - 14s 1ms/step - loss: 0.6280 - accuracy: 0.6479
# Epoch 2/5
# 11559/11559 [==============================] - 13s 1ms/step - loss: 0.6217 - accuracy: 0.6538
# 9030/9030 [==============================] - 6s 626us/step
# Epoch 1/5
# 11559/11559 [==============================] - 14s 1ms/step - loss: 0.6268 - accuracy: 0.6492
# Epoch 2/5
# 11559/11559 [==============================] - 13s 1ms/step - loss: 0.6213 - accuracy: 0.6548
# 9030/9030 [==============================] - 5s 591us/step
# Epoch 1/5
# 11559/11559 [==============================] - 13s 1ms/step - loss: 0.6280 - accuracy: 0.6491
# Epoch 2/5
# 11559/11559 [==============================] - 14s 1ms/step - loss: 0.6224 - accuracy: 0.6539
# 9030/9030 [==============================] - 5s 594us/step
# Epoch 1/5
# 11559/11559 [==============================] - 13s 1ms/step - loss: 0.6268 - accuracy: 0.6498
# Epoch 2/5
# 11559/11559 [==============================] - 13s 1ms/step - loss: 0.6214 - accuracy: 0.6552
# 9030/9030 [==============================] - 5s 581us/step
# Epoch 1/5
# 5780/5780 [==============================] - 7s 1ms/step - loss: 0.6333 - accuracy: 0.6443
# Epoch 2/5
# 5780/5780 [==============================] - 6s 1ms/step - loss: 0.6265 - accuracy: 0.6515
# 9030/9030 [==============================] - 6s 606us/step
# Epoch 1/5
# 5780/5780 [==============================] - 7s 1ms/step - loss: 0.6341 - accuracy: 0.6420
# Epoch 2/5
# 5780/5780 [==============================] - 7s 1ms/step - loss: 0.6258 - accuracy: 0.6527
# 9030/9030 [==============================] - 6s 604us/step
# Epoch 1/5
# 5780/5780 [==============================] - 7s 1ms/step - loss: 0.6350 - accuracy: 0.6418
# Epoch 2/5
# 5780/5780 [==============================] - 7s 1ms/step - loss: 0.6267 - accuracy: 0.6510
# 9030/9030 [==============================] - 5s 591us/step
# Epoch 1/5
# 5780/5780 [==============================] - 7s 1ms/step - loss: 0.6349 - accuracy: 0.6418
# Epoch 2/5
# 5780/5780 [==============================] - 6s 1ms/step - loss: 0.6266 - accuracy: 0.6508
# 9030/9030 [==============================] - 5s 591us/step
# Epoch 1/5
# 5780/5780 [==============================] - 7s 1ms/step - loss: 0.6352 - accuracy: 0.6408
# Epoch 2/5
# 5780/5780 [==============================] - 6s 1ms/step - loss: 0.6269 - accuracy: 0.6504
# 9030/9030 [==============================] - 5s 584us/step
# Epoch 1/5
# 5780/5780 [==============================] - 8s 1ms/step - loss: 0.6313 - accuracy: 0.6446
# Epoch 2/5
# 5780/5780 [==============================] - 7s 1ms/step - loss: 0.6238 - accuracy: 0.6525
# 9030/9030 [==============================] - 6s 608us/step
# Epoch 1/5
# 5780/5780 [==============================] - 8s 1ms/step - loss: 0.6299 - accuracy: 0.6466
# Epoch 2/5
# 5780/5780 [==============================] - 7s 1ms/step - loss: 0.6237 - accuracy: 0.6523
# 9030/9030 [==============================] - 6s 612us/step
# Epoch 1/5
# 5780/5780 [==============================] - 7s 1ms/step - loss: 0.6308 - accuracy: 0.6455
# Epoch 2/5
# 5780/5780 [==============================] - 7s 1ms/step - loss: 0.6237 - accuracy: 0.6528
# 9030/9030 [==============================] - 5s 590us/step
# Epoch 1/5
# 5780/5780 [==============================] - 7s 1ms/step - loss: 0.6313 - accuracy: 0.6451
# Epoch 2/5
# 5780/5780 [==============================] - 7s 1ms/step - loss: 0.6238 - accuracy: 0.6533
# 9030/9030 [==============================] - 5s 579us/step
# Epoch 1/5
# 5780/5780 [==============================] - 7s 1ms/step - loss: 0.6304 - accuracy: 0.6456
# Epoch 2/5
# 5780/5780 [==============================] - 7s 1ms/step - loss: 0.6233 - accuracy: 0.6544
# 9030/9030 [==============================] - 6s 606us/step
# Epoch 1/5
# 5780/5780 [==============================] - 8s 1ms/step - loss: 0.6275 - accuracy: 0.6489
# Epoch 2/5
# 5780/5780 [==============================] - 8s 1ms/step - loss: 0.6219 - accuracy: 0.6544
# 9030/9030 [==============================] - 5s 600us/step
# Epoch 1/5
# 5780/5780 [==============================] - 8s 1ms/step - loss: 0.6280 - accuracy: 0.6487
# Epoch 2/5
# 5780/5780 [==============================] - 8s 1ms/step - loss: 0.6219 - accuracy: 0.6546
# 9030/9030 [==============================] - 5s 594us/step
# Epoch 1/5
# 5780/5780 [==============================] - 8s 1ms/step - loss: 0.6276 - accuracy: 0.6490
# Epoch 2/5
# 5780/5780 [==============================] - 8s 1ms/step - loss: 0.6215 - accuracy: 0.6548
# 9030/9030 [==============================] - 6s 606us/step
# Epoch 1/5
# 5780/5780 [==============================] - 9s 1ms/step - loss: 0.6291 - accuracy: 0.6471
# Epoch 2/5
# 5780/5780 [==============================] - 8s 1ms/step - loss: 0.6225 - accuracy: 0.6541
# 9030/9030 [==============================] - 5s 593us/step
# Epoch 1/5
# 5780/5780 [==============================] - 8s 1ms/step - loss: 0.6289 - accuracy: 0.6474
# Epoch 2/5
# 5780/5780 [==============================] - 8s 1ms/step - loss: 0.6224 - accuracy: 0.6533
# 9030/9030 [==============================] - 6s 624us/step
# Epoch 1/5
# 2890/2890 [==============================] - 4s 1ms/step - loss: 0.6384 - accuracy: 0.6371
# Epoch 2/5
# 2890/2890 [==============================] - 4s 1ms/step - loss: 0.6288 - accuracy: 0.6494
# 9030/9030 [==============================] - 5s 597us/step
# Epoch 1/5
# 2890/2890 [==============================] - 4s 1ms/step - loss: 0.6390 - accuracy: 0.6357
# Epoch 2/5
# 2890/2890 [==============================] - 4s 1ms/step - loss: 0.6270 - accuracy: 0.6501
# 9030/9030 [==============================] - 5s 584us/step
# Epoch 1/5
# 2890/2890 [==============================] - 4s 1ms/step - loss: 0.6366 - accuracy: 0.6405
# Epoch 2/5
# 2890/2890 [==============================] - 4s 1ms/step - loss: 0.6278 - accuracy: 0.6505
# 9030/9030 [==============================] - 5s 585us/step
# Epoch 1/5
# 2890/2890 [==============================] - 5s 1ms/step - loss: 0.6380 - accuracy: 0.6358
# Epoch 2/5
# 2890/2890 [==============================] - 4s 1ms/step - loss: 0.6279 - accuracy: 0.6488
# 9030/9030 [==============================] - 6s 603us/step
# Epoch 1/5
# 2890/2890 [==============================] - 4s 1ms/step - loss: 0.6373 - accuracy: 0.6363
# Epoch 2/5
# 2890/2890 [==============================] - 4s 1ms/step - loss: 0.6268 - accuracy: 0.6491
# 9030/9030 [==============================] - 5s 601us/step
# Epoch 1/5
# 2890/2890 [==============================] - 5s 1ms/step - loss: 0.6339 - accuracy: 0.6430
# Epoch 2/5
# 2890/2890 [==============================] - 4s 1ms/step - loss: 0.6249 - accuracy: 0.6519
# 9030/9030 [==============================] - 6s 603us/step
# Epoch 1/5
# 2890/2890 [==============================] - 5s 1ms/step - loss: 0.6350 - accuracy: 0.6406
# Epoch 2/5
# 2890/2890 [==============================] - 4s 1ms/step - loss: 0.6256 - accuracy: 0.6518
# 9030/9030 [==============================] - 5s 600us/step
# Epoch 1/5
# 2890/2890 [==============================] - 5s 1ms/step - loss: 0.6326 - accuracy: 0.6445
# Epoch 2/5
# 2890/2890 [==============================] - 4s 1ms/step - loss: 0.6245 - accuracy: 0.6524
# 9030/9030 [==============================] - 5s 586us/step
# Epoch 1/5
# 2890/2890 [==============================] - 5s 1ms/step - loss: 0.6347 - accuracy: 0.6394
# Epoch 2/5
# 2890/2890 [==============================] - 4s 2ms/step - loss: 0.6242 - accuracy: 0.6523
# 9030/9030 [==============================] - 5s 594us/step
# Epoch 1/5
# 2890/2890 [==============================] - 5s 1ms/step - loss: 0.6324 - accuracy: 0.6442
# Epoch 2/5
# 2890/2890 [==============================] - 4s 2ms/step - loss: 0.6240 - accuracy: 0.6532
# 9030/9030 [==============================] - 6s 613us/step
# Epoch 1/5
# 2890/2890 [==============================] - 6s 2ms/step - loss: 0.6300 - accuracy: 0.6468
# Epoch 2/5
# 2890/2890 [==============================] - 5s 2ms/step - loss: 0.6231 - accuracy: 0.6537
# 9030/9030 [==============================] - 5s 592us/step
# Epoch 1/5
# 2890/2890 [==============================] - 6s 2ms/step - loss: 0.6311 - accuracy: 0.6443
# Epoch 2/5
# 2890/2890 [==============================] - 5s 2ms/step - loss: 0.6233 - accuracy: 0.6526
# 9030/9030 [==============================] - 5s 590us/step
# Epoch 1/5
# 2890/2890 [==============================] - 6s 2ms/step - loss: 0.6302 - accuracy: 0.6451
# Epoch 2/5
# 2890/2890 [==============================] - 5s 2ms/step - loss: 0.6227 - accuracy: 0.6537
# 9030/9030 [==============================] - 6s 611us/step
# Epoch 1/5
# 2890/2890 [==============================] - 6s 2ms/step - loss: 0.6320 - accuracy: 0.6435
# Epoch 2/5
# 2890/2890 [==============================] - 5s 2ms/step - loss: 0.6227 - accuracy: 0.6540
# 9030/9030 [==============================] - 5s 596us/step
# Epoch 1/5
# 2890/2890 [==============================] - 6s 2ms/step - loss: 0.6311 - accuracy: 0.6448
# Epoch 2/5
# 2890/2890 [==============================] - 5s 2ms/step - loss: 0.6229 - accuracy: 0.6534
# 9030/9030 [==============================] - 5s 591us/step
# Epoch 1/5
# 7224/7224 [==============================] - 10s 1ms/step - loss: 0.6272 - accuracy: 0.6493
# Epoch 2/5
# 7224/7224 [==============================] - 10s 1ms/step - loss: 0.6216 - accuracy: 0.6544
# Best params: {'batch_size': 200, 'epochs': 5, 'loss': 'binary_crossentropy', 'num_layers': 3, 'num_nodes': 22}
# Best average accuracy: 0.6563526313421628
# Epoch 1/5
# 5780/5780 [==============================] - 8s 1ms/step - loss: 0.6283 - accuracy: 0.6478
# Epoch 2/5
# 5780/5780 [==============================] - 8s 1ms/step - loss: 0.6217 - accuracy: 0.6547
# 9030/9030 [==============================] - 6s 670us/step - loss: 0.6202 - accuracy: 0.6573
# 9030/9030 [==============================] - 5s 600us/step
# Epoch 1/5
# 5780/5780 [==============================] - 8s 1ms/step - loss: 0.6203 - accuracy: 0.6561
# Epoch 2/5
# 5780/5780 [==============================] - 8s 1ms/step - loss: 0.6192 - accuracy: 0.6568
# 9030/9030 [==============================] - 6s 674us/step - loss: 0.6195 - accuracy: 0.6583
# 9030/9030 [==============================] - 6s 610us/step
# Epoch 1/5
# 5780/5780 [==============================] - 8s 1ms/step - loss: 0.6180 - accuracy: 0.6579
# Epoch 2/5
# 5780/5780 [==============================] - 8s 1ms/step - loss: 0.6171 - accuracy: 0.6589
# 9030/9030 [==============================] - 6s 679us/step - loss: 0.6225 - accuracy: 0.6600
# 9030/9030 [==============================] - 6s 622us/step
# Epoch 1/5
# 5780/5780 [==============================] - 8s 1ms/step - loss: 0.6160 - accuracy: 0.6606
# Epoch 2/5
# 5780/5780 [==============================] - 8s 1ms/step - loss: 0.6146 - accuracy: 0.6614
# 9030/9030 [==============================] - 6s 673us/step - loss: 0.6143 - accuracy: 0.6641
# 9030/9030 [==============================] - 5s 600us/step
# Epoch 1/5
# 5780/5780 [==============================] - 8s 1ms/step - loss: 0.6134 - accuracy: 0.6628
# Epoch 2/5
# 5780/5780 [==============================] - 8s 1ms/step - loss: 0.6129 - accuracy: 0.6633
# 9030/9030 [==============================] - 6s 674us/step - loss: 0.6143 - accuracy: 0.6632
# 9030/9030 [==============================] - 5s 605us/step
# ###################################
# avg Validation accuracy: 0.6605649828910828
# avg Validation recall: 0.6871186394028915
# avg Validation precision: 0.6524819245157585
# avg Validation F1-score: 0.6693357197764555
# 11288/11288 [==============================] - 7s 618us/step
# ###################################
# Validation accuracy: 0.6631598254423638
# Validation recall: 0.6871116775529712
# Validation precision: 0.6553845137420719
# Validation F1-score: 0.6708731921915524
# 11288/11288 [==============================] - 7s 620us/step
# AUC: 0.7258068530399364
# 11288/11288 [==============================] - 7s 631us/step
# approximate optimal recall: 0.6640033222591362

# %%
dnn_model = DNNModel()
dnn_model.load_file('data/final_train.csv')
dnn_model.scaling_data(StandardScaler, threshold=0.7, over_sampler=SMOTE)
input_dim = dnn_model.get_input_dim()
grid_params = {
    'batch_size': [100, 200, 400], 
    'epochs': [5], 
    'loss': ['binary_crossentropy'], 
    'num_layers': [3], 
    'num_nodes': [input_dim//2, input_dim*3//4, input_dim]}
best_params, _ = dnn_model.searching_best_param_grid(grid_params=grid_params)
# best_params = {'batch_size': 10000, 'epochs': 5, 'loss': 'binary_crossentropy', 'num_layers': 3, 'num_nodes': input_dim*2//3}
metric_result_dictionary = dnn_model.build_model_with_best_params(best_params=best_params, threshold=0.5)
print(f'AUC: {dnn_model.get_roc_auc_score()}')
model_name = dnn_model.get_model_name()
print(f'approximate optimal recall: {dnn_model.draw_precision_recall_curve_plot(min_delta=0.0001)}')
dnn_model.save_model()
# Out:
# ====Data set resampled(oversampled)_SMOTE
# ==label ratio
# True Label:	0.5
# False Label:	0.5
# Epoch 1/5
# 11559/11559 [==============================] - 13s 1ms/step - loss: 0.6488 - accuracy: 0.6237
# Epoch 2/5
# 11559/11559 [==============================] - 12s 1ms/step - loss: 0.6417 - accuracy: 0.6348
# 9030/9030 [==============================] - 6s 648us/step
# Epoch 1/5
# 11559/11559 [==============================] - 12s 1ms/step - loss: 0.6435 - accuracy: 0.6288
# Epoch 2/5
# 11559/11559 [==============================] - 12s 1ms/step - loss: 0.6378 - accuracy: 0.6362
# 9030/9030 [==============================] - 6s 619us/step
# Epoch 1/5
# 11559/11559 [==============================] - 12s 987us/step - loss: 0.6424 - accuracy: 0.6334
# Epoch 2/5
# 11559/11559 [==============================] - 11s 969us/step - loss: 0.6364 - accuracy: 0.6413
# 9030/9030 [==============================] - 6s 605us/step
# Epoch 1/5
# 11559/11559 [==============================] - 12s 968us/step - loss: 0.6478 - accuracy: 0.6278
# Epoch 2/5
# 11559/11559 [==============================] - 11s 969us/step - loss: 0.6399 - accuracy: 0.6377
# 9030/9030 [==============================] - 5s 595us/step
# Epoch 1/5
# 11559/11559 [==============================] - 11s 948us/step - loss: 0.6436 - accuracy: 0.6307
# Epoch 2/5
# 11559/11559 [==============================] - 11s 947us/step - loss: 0.6370 - accuracy: 0.6392
# 9030/9030 [==============================] - 6s 598us/step
# Epoch 1/5
# 11559/11559 [==============================] - 12s 1ms/step - loss: 0.6366 - accuracy: 0.6416
# Epoch 2/5
# 11559/11559 [==============================] - 12s 1ms/step - loss: 0.6316 - accuracy: 0.6468
# 9030/9030 [==============================] - 5s 597us/step
# Epoch 1/5
# 11559/11559 [==============================] - 12s 1ms/step - loss: 0.6371 - accuracy: 0.6406
# Epoch 2/5
# 11559/11559 [==============================] - 12s 1ms/step - loss: 0.6310 - accuracy: 0.6471
# 9030/9030 [==============================] - 6s 606us/step
# Epoch 1/5
# 11559/11559 [==============================] - 12s 1ms/step - loss: 0.6370 - accuracy: 0.6415
# Epoch 2/5
# 11559/11559 [==============================] - 12s 999us/step - loss: 0.6319 - accuracy: 0.6467
# 9030/9030 [==============================] - 5s 595us/step
# Epoch 1/5
# 11559/11559 [==============================] - 12s 1ms/step - loss: 0.6378 - accuracy: 0.6396
# Epoch 2/5
# 11559/11559 [==============================] - 12s 1ms/step - loss: 0.6324 - accuracy: 0.6463
# 9030/9030 [==============================] - 6s 604us/step
# Epoch 1/5
# 11559/11559 [==============================] - 12s 1ms/step - loss: 0.6360 - accuracy: 0.6426
# Epoch 2/5
# 11559/11559 [==============================] - 12s 1ms/step - loss: 0.6303 - accuracy: 0.6483
# 9030/9030 [==============================] - 6s 607us/step
# Epoch 1/5
# 11559/11559 [==============================] - 12s 1ms/step - loss: 0.6356 - accuracy: 0.6420
# Epoch 2/5
# 11559/11559 [==============================] - 12s 1ms/step - loss: 0.6300 - accuracy: 0.6485
# 9030/9030 [==============================] - 5s 602us/step
# Epoch 1/5
# 11559/11559 [==============================] - 12s 1ms/step - loss: 0.6343 - accuracy: 0.6428
# Epoch 2/5
# 11559/11559 [==============================] - 12s 1ms/step - loss: 0.6291 - accuracy: 0.6481
# 9030/9030 [==============================] - 5s 587us/step
# Epoch 1/5
# 11559/11559 [==============================] - 12s 1ms/step - loss: 0.6347 - accuracy: 0.6417
# Epoch 2/5
# 11559/11559 [==============================] - 12s 1ms/step - loss: 0.6292 - accuracy: 0.6471
# 9030/9030 [==============================] - 5s 599us/step
# Epoch 1/5
# 11559/11559 [==============================] - 12s 1ms/step - loss: 0.6335 - accuracy: 0.6439
# Epoch 2/5
# 11559/11559 [==============================] - 12s 1ms/step - loss: 0.6289 - accuracy: 0.6479
# 9030/9030 [==============================] - 5s 596us/step
# Epoch 1/5
# 11559/11559 [==============================] - 13s 1ms/step - loss: 0.6340 - accuracy: 0.6425
# Epoch 2/5
# 11559/11559 [==============================] - 12s 1ms/step - loss: 0.6284 - accuracy: 0.6486
# 9030/9030 [==============================] - 5s 585us/step
# Epoch 1/5
# 5780/5780 [==============================] - 6s 1ms/step - loss: 0.6508 - accuracy: 0.6222
# Epoch 2/5
# 5780/5780 [==============================] - 6s 1ms/step - loss: 0.6414 - accuracy: 0.6349
# 9030/9030 [==============================] - 5s 596us/step
# Epoch 1/5
# 5780/5780 [==============================] - 6s 1ms/step - loss: 0.6463 - accuracy: 0.6255
# Epoch 2/5
# 5780/5780 [==============================] - 6s 1ms/step - loss: 0.6373 - accuracy: 0.6396
# 9030/9030 [==============================] - 5s 596us/step
# Epoch 1/5
# 5780/5780 [==============================] - 6s 1ms/step - loss: 0.6472 - accuracy: 0.6237
# Epoch 2/5
# 5780/5780 [==============================] - 6s 1ms/step - loss: 0.6368 - accuracy: 0.6407
# 9030/9030 [==============================] - 6s 613us/step
# Epoch 1/5
# 5780/5780 [==============================] - 6s 1ms/step - loss: 0.6492 - accuracy: 0.6243
# Epoch 2/5
# 5780/5780 [==============================] - 6s 1ms/step - loss: 0.6372 - accuracy: 0.6414
# 9030/9030 [==============================] - 6s 605us/step
# Epoch 1/5
# 5780/5780 [==============================] - 6s 1ms/step - loss: 0.6486 - accuracy: 0.6199
# Epoch 2/5
# 5780/5780 [==============================] - 6s 1ms/step - loss: 0.6381 - accuracy: 0.6389
# 9030/9030 [==============================] - 5s 593us/step
# Epoch 1/5
# 5780/5780 [==============================] - 7s 1ms/step - loss: 0.6452 - accuracy: 0.6308
# Epoch 2/5
# 5780/5780 [==============================] - 6s 1ms/step - loss: 0.6355 - accuracy: 0.6427
# 9030/9030 [==============================] - 5s 594us/step
# Epoch 1/5
# 5780/5780 [==============================] - 7s 1ms/step - loss: 0.6403 - accuracy: 0.6357
# Epoch 2/5
# 5780/5780 [==============================] - 6s 1ms/step - loss: 0.6322 - accuracy: 0.6448
# 9030/9030 [==============================] - 5s 601us/step
# Epoch 1/5
# 5780/5780 [==============================] - 7s 1ms/step - loss: 0.6370 - accuracy: 0.6398
# Epoch 2/5
# 5780/5780 [==============================] - 6s 1ms/step - loss: 0.6308 - accuracy: 0.6479
# 9030/9030 [==============================] - 5s 602us/step
# Epoch 1/5
# 5780/5780 [==============================] - 7s 1ms/step - loss: 0.6396 - accuracy: 0.6359
# Epoch 2/5
# 5780/5780 [==============================] - 6s 1ms/step - loss: 0.6331 - accuracy: 0.6443
# 9030/9030 [==============================] - 5s 595us/step
# Epoch 1/5
# 5780/5780 [==============================] - 7s 1ms/step - loss: 0.6383 - accuracy: 0.6381
# Epoch 2/5
# 5780/5780 [==============================] - 6s 1ms/step - loss: 0.6315 - accuracy: 0.6456
# 9030/9030 [==============================] - 5s 598us/step
# Epoch 1/5
# 5780/5780 [==============================] - 7s 1ms/step - loss: 0.6367 - accuracy: 0.6400
# Epoch 2/5
# 5780/5780 [==============================] - 7s 1ms/step - loss: 0.6301 - accuracy: 0.6476
# 9030/9030 [==============================] - 5s 599us/step
# Epoch 1/5
# 5780/5780 [==============================] - 7s 1ms/step - loss: 0.6363 - accuracy: 0.6408
# Epoch 2/5
# 5780/5780 [==============================] - 7s 1ms/step - loss: 0.6288 - accuracy: 0.6493
# 9030/9030 [==============================] - 6s 630us/step
# Epoch 1/5
# 5780/5780 [==============================] - 7s 1ms/step - loss: 0.6364 - accuracy: 0.6403
# Epoch 2/5
# 5780/5780 [==============================] - 7s 1ms/step - loss: 0.6295 - accuracy: 0.6477
# 9030/9030 [==============================] - 5s 595us/step
# Epoch 1/5
# 5780/5780 [==============================] - 7s 1ms/step - loss: 0.6356 - accuracy: 0.6421
# Epoch 2/5
# 5780/5780 [==============================] - 7s 1ms/step - loss: 0.6294 - accuracy: 0.6486
# 9030/9030 [==============================] - 5s 592us/step
# Epoch 1/5
# 5780/5780 [==============================] - 7s 1ms/step - loss: 0.6342 - accuracy: 0.6429
# Epoch 2/5
# 5780/5780 [==============================] - 7s 1ms/step - loss: 0.6287 - accuracy: 0.6491
# 9030/9030 [==============================] - 5s 601us/step
# Epoch 1/5
# 2890/2890 [==============================] - 4s 1ms/step - loss: 0.6499 - accuracy: 0.6190
# Epoch 2/5
# 2890/2890 [==============================] - 3s 1ms/step - loss: 0.6411 - accuracy: 0.6333
# 9030/9030 [==============================] - 5s 593us/step
# Epoch 1/5
# 2890/2890 [==============================] - 4s 1ms/step - loss: 0.6510 - accuracy: 0.6211
# Epoch 2/5
# 2890/2890 [==============================] - 3s 1ms/step - loss: 0.6392 - accuracy: 0.6386
# 9030/9030 [==============================] - 5s 592us/step
# Epoch 1/5
# 2890/2890 [==============================] - 4s 1ms/step - loss: 0.6532 - accuracy: 0.6220
# Epoch 2/5
# 2890/2890 [==============================] - 3s 1ms/step - loss: 0.6411 - accuracy: 0.6362
# 9030/9030 [==============================] - 5s 594us/step
# Epoch 1/5
# 2890/2890 [==============================] - 4s 1ms/step - loss: 0.6490 - accuracy: 0.6226
# Epoch 2/5
# 2890/2890 [==============================] - 3s 1ms/step - loss: 0.6380 - accuracy: 0.6379
# 9030/9030 [==============================] - 5s 590us/step
# Epoch 1/5
# 2890/2890 [==============================] - 4s 1ms/step - loss: 0.6501 - accuracy: 0.6218
# Epoch 2/5
# 2890/2890 [==============================] - 3s 1ms/step - loss: 0.6382 - accuracy: 0.6406
# 9030/9030 [==============================] - 5s 595us/step
# Epoch 1/5
# 2890/2890 [==============================] - 4s 1ms/step - loss: 0.6462 - accuracy: 0.6282
# Epoch 2/5
# 2890/2890 [==============================] - 4s 1ms/step - loss: 0.6333 - accuracy: 0.6454
# 9030/9030 [==============================] - 5s 601us/step
# Epoch 1/5
# 2890/2890 [==============================] - 4s 1ms/step - loss: 0.6564 - accuracy: 0.6181
# Epoch 2/5
# 2890/2890 [==============================] - 4s 1ms/step - loss: 0.6440 - accuracy: 0.6318
# 9030/9030 [==============================] - 5s 594us/step
# Epoch 1/5
# 2890/2890 [==============================] - 4s 1ms/step - loss: 0.6464 - accuracy: 0.6300
# Epoch 2/5
# 2890/2890 [==============================] - 4s 1ms/step - loss: 0.6360 - accuracy: 0.6436
# 9030/9030 [==============================] - 5s 591us/step
# Epoch 1/5
# 2890/2890 [==============================] - 4s 1ms/step - loss: 0.6468 - accuracy: 0.6290
# Epoch 2/5
# 2890/2890 [==============================] - 4s 1ms/step - loss: 0.6347 - accuracy: 0.6446
# 9030/9030 [==============================] - 5s 594us/step
# Epoch 1/5
# 2890/2890 [==============================] - 4s 1ms/step - loss: 0.6483 - accuracy: 0.6257
# Epoch 2/5
# 2890/2890 [==============================] - 4s 1ms/step - loss: 0.6366 - accuracy: 0.6411
# 9030/9030 [==============================] - 5s 599us/step
# Epoch 1/5
# 2890/2890 [==============================] - 5s 1ms/step - loss: 0.6399 - accuracy: 0.6352
# Epoch 2/5
# 2890/2890 [==============================] - 4s 1ms/step - loss: 0.6306 - accuracy: 0.6471
# 9030/9030 [==============================] - 5s 592us/step
# Epoch 1/5
# 2890/2890 [==============================] - 5s 2ms/step - loss: 0.6377 - accuracy: 0.6397
# Epoch 2/5
# 2890/2890 [==============================] - 5s 2ms/step - loss: 0.6303 - accuracy: 0.6480
# 9030/9030 [==============================] - 5s 602us/step
# Epoch 1/5
# 2890/2890 [==============================] - 4s 1ms/step - loss: 0.6370 - accuracy: 0.6387
# Epoch 2/5
# 2890/2890 [==============================] - 4s 1ms/step - loss: 0.6297 - accuracy: 0.6475
# 9030/9030 [==============================] - 5s 599us/step
# Epoch 1/5
# 2890/2890 [==============================] - 5s 1ms/step - loss: 0.6403 - accuracy: 0.6358
# Epoch 2/5
# 2890/2890 [==============================] - 4s 1ms/step - loss: 0.6311 - accuracy: 0.6469
# 9030/9030 [==============================] - 5s 603us/step
# Epoch 1/5
# 2890/2890 [==============================] - 5s 1ms/step - loss: 0.6397 - accuracy: 0.6380
# Epoch 2/5
# 2890/2890 [==============================] - 4s 1ms/step - loss: 0.6298 - accuracy: 0.6481
# 9030/9030 [==============================] - 6s 616us/step
# Epoch 1/5
# 14448/14448 [==============================] - 16s 1ms/step - loss: 0.6332 - accuracy: 0.6430
# Epoch 2/5
# 14448/14448 [==============================] - 15s 1ms/step - loss: 0.6288 - accuracy: 0.6480
# Best params: {'batch_size': 100, 'epochs': 5, 'loss': 'binary_crossentropy', 'num_layers': 3, 'num_nodes': 13}
# Best average accuracy: 0.6500610813298773
# Epoch 1/5
# 11559/11559 [==============================] - 12s 1ms/step - loss: 0.6345 - accuracy: 0.6420
# Epoch 2/5
# 11559/11559 [==============================] - 12s 1ms/step - loss: 0.6286 - accuracy: 0.6488
# 9030/9030 [==============================] - 6s 671us/step - loss: 0.6267 - accuracy: 0.6515
# 9030/9030 [==============================] - 5s 601us/step
# Epoch 1/5
# 11559/11559 [==============================] - 12s 1ms/step - loss: 0.6276 - accuracy: 0.6497
# Epoch 2/5
# 11559/11559 [==============================] - 12s 1ms/step - loss: 0.6273 - accuracy: 0.6500
# 9030/9030 [==============================] - 6s 681us/step - loss: 0.6262 - accuracy: 0.6511
# 9030/9030 [==============================] - 5s 605us/step
# Epoch 1/5
# 11559/11559 [==============================] - 12s 1ms/step - loss: 0.6268 - accuracy: 0.6499
# Epoch 2/5
# 11559/11559 [==============================] - 13s 1ms/step - loss: 0.6265 - accuracy: 0.6498
# 9030/9030 [==============================] - 6s 684us/step - loss: 0.6274 - accuracy: 0.6520
# 9030/9030 [==============================] - 6s 608us/step
# Epoch 1/5
# 11559/11559 [==============================] - 12s 1ms/step - loss: 0.6265 - accuracy: 0.6504
# Epoch 2/5
# 11559/11559 [==============================] - 12s 1ms/step - loss: 0.6262 - accuracy: 0.6503
# 9030/9030 [==============================] - 6s 690us/step - loss: 0.6268 - accuracy: 0.6523
# 9030/9030 [==============================] - 5s 606us/step
# Epoch 1/5
# 11559/11559 [==============================] - 13s 1ms/step - loss: 0.6258 - accuracy: 0.6506
# Epoch 2/5
# 11559/11559 [==============================] - 12s 1ms/step - loss: 0.6258 - accuracy: 0.6512
# 9030/9030 [==============================] - 6s 684us/step - loss: 0.6267 - accuracy: 0.6513
# 9030/9030 [==============================] - 6s 610us/step
# ###################################
# avg Validation accuracy: 0.6516211628913879
# avg Validation recall: 0.6833484892390882
# avg Validation precision: 0.6425938776991595
# avg Validation F1-score: 0.6623223624668064
# 11288/11288 [==============================] - 7s 619us/step
# ###################################
# Validation accuracy: 0.6512688651331158
# Validation recall: 0.6743459559052718
# Validation precision: 0.6442723843557673
# Validation F1-score: 0.6589662279469745
# 11288/11288 [==============================] - 7s 609us/step
# AUC: 0.7102864071810937
# 11288/11288 [==============================] - 7s 617us/step
# approximate optimal recall: [[1.00000000e+00 1.00000000e+00 1.00000000e+00 ... 1.10741971e-05
#   5.53709856e-06 0.00000000e+00]]
