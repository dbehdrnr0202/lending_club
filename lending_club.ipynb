# %%
import pandas as pd
import numpy as np
# Out:
# C:\Users\Hi\AppData\Local\Temp\ipykernel_3948\2162656668.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
origin_data = pd.read_csv("data/lending_club_2020_train.csv")
origin_data.head()
# Out:
# C:\Users\Hi\AppData\Local\Temp\ipykernel_3948\1849447870.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   origin_data = pd.read_csv("data/lending_club_2020_train.csv")
#           id  loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  \
# 0  124989905     6000.0       6000.0           6000.0   36 months    7.97%
# 1  139665484    35000.0      35000.0          35000.0   60 months   14.47%
# 2   84253847    23200.0      23200.0          23200.0   60 months   24.99%
# 3  126296074     4500.0       4500.0           4500.0   36 months    9.93%
# 4  148913312    15000.0      15000.0          15000.0   36 months   16.40%
#
#    installment grade sub_grade           emp_title  ... hardship_start_date  \
# 0       187.94     A        A5             Teacher  ...                 NaN
# 1       822.95     C        C2  Product Specialist  ...                 NaN
# 2       680.82     E        E4  Production Foreman  ...                 NaN
# 3       145.06     B        B2      Office Manager  ...                 NaN
# 4       530.33     C        C4           Secretary  ...            May-2020
#
#   hardship_end_date  payment_plan_start_date hardship_length hardship_dpd  \
# 0               NaN                      NaN             NaN          NaN
# 1               NaN                      NaN             NaN          NaN
# 2               NaN                      NaN             NaN          NaN
# 3               NaN                      NaN             NaN          NaN
# 4          Jul-2020                 May-2020             2.0          0.0
#
#   hardship_loan_status orig_projected_additional_accrued_interest  \
# 0                  NaN                                        NaN
# 1                  NaN                                        NaN
# 2                  NaN                                        NaN
# 3                  NaN                                        NaN
# 4               ACTIVE                                     413.83
#
#   hardship_payoff_balance_amount hardship_last_payment_amount  \
# 0                            NaN                          NaN
# 1                            NaN                          NaN
# 2                            NaN                          NaN
# 3                            NaN                          NaN
# 4                       11025.25                        54.62
#
#   debt_settlement_flag
# 0                    N
# 1                    N
# 2                    Y
# 3                    N
# 4                    N
#
# [5 rows x 141 columns]

# %%
origin_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1755295 entries, 0 to 1755294
# Columns: 141 entries, id to debt_settlement_flag
# dtypes: float64(106), object(35)
# memory usage: 1.8+ GB

# %%
origin_data.describe()
# Out:
#           loan_amnt   funded_amnt  funded_amnt_inv   installment  \
# count  1.755294e+06  1.755294e+06     1.755294e+06  1.755294e+06
# mean   1.535079e+04  1.534665e+04     1.533186e+04  4.521032e+02
# std    9.472634e+03  9.471411e+03     9.474863e+03  2.726766e+02
# min    5.000000e+02  5.000000e+02     0.000000e+00  7.610000e+00
# 25%    8.000000e+03  8.000000e+03     8.000000e+03  2.533500e+02
# 50%    1.300000e+04  1.300000e+04     1.300000e+04  3.816600e+02
# 75%    2.000000e+04  2.000000e+04     2.000000e+04  6.033500e+02
# max    4.000000e+04  4.000000e+04     4.000000e+04  1.719830e+03
#
#          annual_inc           dti   delinq_2yrs  fico_range_low  \
# count  1.755292e+06  1.753433e+06  1.755278e+06    1.755294e+06
# mean   7.994798e+04  1.930943e+01  2.893348e-01    7.005373e+02
# std    1.267416e+05  1.592243e+01  8.430192e-01    3.378152e+01
# min    0.000000e+00  0.000000e+00  0.000000e+00    6.100000e+02
# 25%    4.700000e+04  1.208000e+01  0.000000e+00    6.750000e+02
# 50%    6.600000e+04  1.810000e+01  0.000000e+00    6.950000e+02
# 75%    9.500000e+04  2.489000e+01  0.000000e+00    7.200000e+02
# max    1.100000e+08  9.990000e+02  5.800000e+01    8.450000e+02
#
#        fico_range_high  inq_last_6mths  ...  sec_app_num_rev_accts  \
# count     1.755294e+06    1.755278e+06  ...          118705.000000
# mean      7.045375e+02    5.543441e-01  ...              12.566354
# std       3.378246e+01    8.597982e-01  ...               8.222663
# min       6.140000e+02    0.000000e+00  ...               0.000000
# 25%       6.790000e+02    0.000000e+00  ...               7.000000
# 50%       6.990000e+02    0.000000e+00  ...              11.000000
# 75%       7.240000e+02    1.000000e+00  ...              17.000000
# max       8.500000e+02    3.100000e+01  ...             110.000000
#
#        sec_app_chargeoff_within_12_mths  sec_app_collections_12_mths_ex_med  \
# count                     118705.000000                       118705.000000
# mean                           0.037454                            0.067065
# std                            0.354166                            0.366782
# min                            0.000000                            0.000000
# 25%                            0.000000                            0.000000
# 50%                            0.000000                            0.000000
# 75%                            0.000000                            0.000000
# max                           21.000000                           20.000000
#
#        deferral_term  hardship_amount  hardship_length  hardship_dpd  \
# count   86036.000000    109131.000000     86036.000000  86035.000000
# mean        2.234820       119.600574         2.234820      2.289522
# std         0.568368       246.988946         0.568368      6.130802
# min         0.000000         0.000000         0.000000      0.000000
# 25%         2.000000         0.000000         2.000000      0.000000
# 50%         2.000000         0.000000         2.000000      0.000000
# 75%         2.000000       100.190000         2.000000      0.000000
# max         4.000000      2797.500000         4.000000     67.000000
#
#        orig_projected_additional_accrued_interest  \
# count                               107480.000000
# mean                                   370.207540
# std                                    472.563626
# min                                      0.000000
# 25%                                    104.547500
# 50%                                    248.850000
# 75%                                    483.692625
# max                                  11581.820000
#
#        hardship_payoff_balance_amount  hardship_last_payment_amount
# count                    109131.00000                 109131.000000
# mean                      11990.70022                    749.234284
# std                        9169.15688                   2114.495770
# min                           0.00000                      0.000000
# 25%                        4756.05000                    259.080000
# 50%                        9971.20000                    422.720000
# 75%                       17629.36500                    679.290000
# max                       42088.07000                  40270.980000
#
# [8 rows x 106 columns]

# %%
origin_data.select_dtypes("object").info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1755295 entries, 0 to 1755294
# Data columns (total 35 columns):
#  #   Column                     Dtype
# ---  ------                     -----
#  0   id                         object
#  1   term                       object
#  2   int_rate                   object
#  3   grade                      object
#  4   sub_grade                  object
#  5   emp_title                  object
#  6   emp_length                 object
#  7   home_ownership             object
#  8   verification_status        object
#  9   issue_d                    object
#  10  loan_status                object
#  11  pymnt_plan                 object
#  12  url                        object
#  13  purpose                    object
#  14  title                      object
#  15  zip_code                   object
#  16  addr_state                 object
#  17  earliest_cr_line           object
#  18  revol_util                 object
#  19  initial_list_status        object
#  20  last_pymnt_d               object
#  21  next_pymnt_d               object
#  22  last_credit_pull_d         object
#  23  application_type           object
#  24  verification_status_joint  object
#  25  sec_app_earliest_cr_line   object
#  26  hardship_flag              object
#  27  hardship_type              object
#  28  hardship_reason            object
#  29  hardship_status            object
#  30  hardship_start_date        object
#  31  hardship_end_date          object
#  32  payment_plan_start_date    object
#  33  hardship_loan_status       object
#  34  debt_settlement_flag       object
# dtypes: object(35)
# memory usage: 468.7+ MB

# %%
origin_data.select_dtypes("object").describe()
# Out:
#                id        term int_rate    grade sub_grade emp_title  \
# count     1755295     1755294  1755294  1755294   1755294   1596894
# unique    1755295           2      693        7        35    404167
# top     124989905   36 months    8.19%        B        B4   Teacher
# freq            1     1236014    41159   515082    111180     30092
#
#        emp_length home_ownership verification_status   issue_d  ...  \
# count     1632210        1755294             1755294   1755294  ...
# unique         11              6                   3       160  ...
# top     10+ years       MORTGAGE     Source Verified  Mar-2016  ...
# freq       567404         862836              686265     37347  ...
#
#        sec_app_earliest_cr_line hardship_flag hardship_type hardship_reason  \
# count                    118705       1732203         86036           86031
# unique                      674             2             9              17
# top                    Aug-2006             N     CVD19SKIP      INCOMECURT
# freq                       1081       1659249         78089           50497
#
#        hardship_status hardship_start_date hardship_end_date  \
# count            86034               86036             86036
# unique               4                  46                47
# top             ACTIVE            Apr-2020          Jun-2020
# freq             72952               62461             47634
#
#        payment_plan_start_date hardship_loan_status debt_settlement_flag
# count                    86036                85908              1755294
# unique                      46                   13                    2
# top                   Apr-2020               ACTIVE                    N
# freq                     46614                69831              1724502
#
# [4 rows x 35 columns]

# %%
origin_data.select_dtypes("float64").describe()
# Out:
#           loan_amnt   funded_amnt  funded_amnt_inv   installment  \
# count  1.755294e+06  1.755294e+06     1.755294e+06  1.755294e+06
# mean   1.535079e+04  1.534665e+04     1.533186e+04  4.521032e+02
# std    9.472634e+03  9.471411e+03     9.474863e+03  2.726766e+02
# min    5.000000e+02  5.000000e+02     0.000000e+00  7.610000e+00
# 25%    8.000000e+03  8.000000e+03     8.000000e+03  2.533500e+02
# 50%    1.300000e+04  1.300000e+04     1.300000e+04  3.816600e+02
# 75%    2.000000e+04  2.000000e+04     2.000000e+04  6.033500e+02
# max    4.000000e+04  4.000000e+04     4.000000e+04  1.719830e+03
#
#          annual_inc           dti   delinq_2yrs  fico_range_low  \
# count  1.755292e+06  1.753433e+06  1.755278e+06    1.755294e+06
# mean   7.994798e+04  1.930943e+01  2.893348e-01    7.005373e+02
# std    1.267416e+05  1.592243e+01  8.430192e-01    3.378152e+01
# min    0.000000e+00  0.000000e+00  0.000000e+00    6.100000e+02
# 25%    4.700000e+04  1.208000e+01  0.000000e+00    6.750000e+02
# 50%    6.600000e+04  1.810000e+01  0.000000e+00    6.950000e+02
# 75%    9.500000e+04  2.489000e+01  0.000000e+00    7.200000e+02
# max    1.100000e+08  9.990000e+02  5.800000e+01    8.450000e+02
#
#        fico_range_high  inq_last_6mths  ...  sec_app_num_rev_accts  \
# count     1.755294e+06    1.755278e+06  ...          118705.000000
# mean      7.045375e+02    5.543441e-01  ...              12.566354
# std       3.378246e+01    8.597982e-01  ...               8.222663
# min       6.140000e+02    0.000000e+00  ...               0.000000
# 25%       6.790000e+02    0.000000e+00  ...               7.000000
# 50%       6.990000e+02    0.000000e+00  ...              11.000000
# 75%       7.240000e+02    1.000000e+00  ...              17.000000
# max       8.500000e+02    3.100000e+01  ...             110.000000
#
#        sec_app_chargeoff_within_12_mths  sec_app_collections_12_mths_ex_med  \
# count                     118705.000000                       118705.000000
# mean                           0.037454                            0.067065
# std                            0.354166                            0.366782
# min                            0.000000                            0.000000
# 25%                            0.000000                            0.000000
# 50%                            0.000000                            0.000000
# 75%                            0.000000                            0.000000
# max                           21.000000                           20.000000
#
#        deferral_term  hardship_amount  hardship_length  hardship_dpd  \
# count   86036.000000    109131.000000     86036.000000  86035.000000
# mean        2.234820       119.600574         2.234820      2.289522
# std         0.568368       246.988946         0.568368      6.130802
# min         0.000000         0.000000         0.000000      0.000000
# 25%         2.000000         0.000000         2.000000      0.000000
# 50%         2.000000         0.000000         2.000000      0.000000
# 75%         2.000000       100.190000         2.000000      0.000000
# max         4.000000      2797.500000         4.000000     67.000000
#
#        orig_projected_additional_accrued_interest  \
# count                               107480.000000
# mean                                   370.207540
# std                                    472.563626
# min                                      0.000000
# 25%                                    104.547500
# 50%                                    248.850000
# 75%                                    483.692625
# max                                  11581.820000
#
#        hardship_payoff_balance_amount  hardship_last_payment_amount
# count                    109131.00000                 109131.000000
# mean                      11990.70022                    749.234284
# std                        9169.15688                   2114.495770
# min                           0.00000                      0.000000
# 25%                        4756.05000                    259.080000
# 50%                        9971.20000                    422.720000
# 75%                       17629.36500                    679.290000
# max                       42088.07000                  40270.980000
#
# [8 rows x 106 columns]

# %%
columns = origin_data.columns
column_list = columns.to_list()
with open("data/columns.txt", mode="w") as f:
    for column in column_list:
        f.write(column + "\n")

# %%
origin_data.isnull().sum()
# Out:
# id                                                  0
# loan_amnt                                           1
# funded_amnt                                         1
# funded_amnt_inv                                     1
# term                                                1
#                                                ...
# hardship_loan_status                          1669387
# orig_projected_additional_accrued_interest    1647815
# hardship_payoff_balance_amount                1646164
# hardship_last_payment_amount                  1646164
# debt_settlement_flag                                1
# Length: 141, dtype: int64

# %%
origin_data.select_dtypes("float64").isnull().sum()
# Out:
# loan_amnt                                           1
# funded_amnt                                         1
# funded_amnt_inv                                     1
# installment                                         1
# annual_inc                                          3
#                                                ...
# hardship_length                               1669259
# hardship_dpd                                  1669260
# orig_projected_additional_accrued_interest    1647815
# hardship_payoff_balance_amount                1646164
# hardship_last_payment_amount                  1646164
# Length: 106, dtype: int64

# %%
origin_data.select_dtypes("object").isnull().sum()
# Out:
# id                                 0
# term                               1
# int_rate                           1
# grade                              1
# sub_grade                          1
# emp_title                     158401
# emp_length                    123085
# home_ownership                     1
# verification_status                1
# issue_d                            1
# loan_status                        1
# pymnt_plan                         1
# url                                1
# purpose                            1
# title                          14044
# zip_code                           1
# addr_state                         1
# earliest_cr_line                  17
# revol_util                      1588
# initial_list_status                1
# last_pymnt_d                    3030
# next_pymnt_d                 1115889
# last_credit_pull_d                42
# application_type                   1
# verification_status_joint    1638412
# sec_app_earliest_cr_line     1636590
# hardship_flag                  23092
# hardship_type                1669259
# hardship_reason              1669264
# hardship_status              1669261
# hardship_start_date          1669259
# hardship_end_date            1669259
# payment_plan_start_date      1669259
# hardship_loan_status         1669387
# debt_settlement_flag               1
# dtype: int64

# %%
origin_data["loan_status"].value_counts()
# 여기서 loan_status가 Current인 값들은 제외해도 되지않을까
# 여기서 중요한 target_field는 (Fully Paid, Charged Off)이다.
# Out:
# loan_status
# Fully Paid                                             898522
# Current                                                618688
# Charged Off                                            217366
# Late (31-120 days)                                       9840
# In Grace Period                                          6049
# Late (16-30 days)                                        1620
# Issued                                                   1258
# Does not meet the credit policy. Status:Fully Paid       1223
# Does not meet the credit policy. Status:Charged Off       460
# Default                                                   268
# Name: count, dtype: int64

# %%
origin_data["loan_status"].unique()
# Out:
# array(['Fully Paid', 'Current', 'Charged Off', 'Late (16-30 days)',
#        'Late (31-120 days)', 'In Grace Period', 'Issued',
#        'Does not meet the credit policy. Status:Fully Paid',
#        'Does not meet the credit policy. Status:Charged Off', 'Default',
#        nan], dtype=object)

# %%
origin_data.select_dtypes("object").value_counts()
# Out:
# id         term       int_rate  grade  sub_grade  emp_title                      emp_length  home_ownership  verification_status  issue_d   loan_status  pymnt_plan  url                                                                 purpose             title                    zip_code  addr_state  earliest_cr_line  revol_util  initial_list_status  last_pymnt_d  next_pymnt_d  last_credit_pull_d  application_type  verification_status_joint  sec_app_earliest_cr_line  hardship_flag  hardship_type  hardship_reason     hardship_status  hardship_start_date  hardship_end_date  payment_plan_start_date  hardship_loan_status  debt_settlement_flag
# 99597998   60 months  13.99%    C      C3         Real Estate Broker             3 years     MORTGAGE        Verified             Apr-2017  Current      n           https://lendingclub.com/browse/loanDetail.action?loan_id=99597998   debt_consolidation  Debt consolidation       272xx     NC          Aug-2001          88.5%       w                    Jun-2020      Aug-2020      May-2020            Joint App         Source Verified            Dec-2000                  Y              CVD19SKIP      INCOME_CURTAILMENT  ACTIVE           May-2020             Jul-2020           May-2020                 ACTIVE                N                       1
# 152817648  60 months  14.74%    C      C2         Front Office Administrator     1 year      MORTGAGE        Source Verified      Jun-2019  Current      n           https://lendingclub.com/browse/loanDetail.action?loan_id=152817648  other               Other                    199xx     DE          Jun-2005          16.2%       w                    Mar-2020      Jul-2020      May-2020            Joint App         Source Verified            Feb-2016                  Y              CVD19SKIP      UNEMPLOYED          ACTIVE           Apr-2020             Jun-2020           Apr-2020                 ACTIVE                N                       1
# 152770292  60 months  13.08%    B      B5         Manager                        < 1 year    MORTGAGE        Source Verified      Jun-2019  Current      n           https://lendingclub.com/browse/loanDetail.action?loan_id=152770292  home_improvement    Home improvement         852xx     AZ          Sep-2005          69.3%       w                    Jul-2020      Sep-2020      May-2020            Joint App         Source Verified            Jul-2002                  Y              CVD19SKIP      INCOME_CURTAILMENT  ACTIVE           May-2020             Aug-2020           Jun-2020                 ACTIVE                N                       1
# 152773355  36 months   8.19%    A      A4         Supervisor                     10+ years   RENT            Verified             Jun-2019  Current      n           https://lendingclub.com/browse/loanDetail.action?loan_id=152773355  debt_consolidation  Debt consolidation       070xx     NJ          Jun-2006          20.3%       w                    Jun-2020      Aug-2020      May-2020            Joint App         Verified                   Jun-2006                  Y              CVD19SKIP      UNEMPLOYED          ACTIVE           Apr-2020             Jul-2020           May-2020                 ACTIVE                N                       1
# 152777158  36 months  10.33%    B      B1         Care provider                  3 years     OWN             Not Verified         Jun-2019  Current      n           https://lendingclub.com/browse/loanDetail.action?loan_id=152777158  credit_card         Credit card refinancing  112xx     NY          Oct-1997          67.6%       w                    Jun-2020      Aug-2020      May-2020            Joint App         Not Verified               Nov-2014                  Y              CVD19SKIP      INCOMECURT          ACTIVE           Apr-2020             Jul-2020           May-2020                 ACTIVE                N                       1
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        ..
# 137227774  36 months  16.91%    C      C5         Paraprofessional               10+ years   MORTGAGE        Verified             Aug-2018  Current      n           https://lendingclub.com/browse/loanDetail.action?loan_id=137227774  debt_consolidation  Debt consolidation       300xx     GA          Jul-2013          62.8%       w                    Jun-2020      Aug-2020      May-2020            Joint App         Source Verified            Feb-2005                  Y              CVD19SKIP      INCOMECURT          ACTIVE           Apr-2020             Jun-2020           May-2020                 ACTIVE                N                       1
# 137219032  60 months  18.94%    D      D2         Senior Acquisition Specialist  5 years     MORTGAGE        Source Verified      Jul-2018  Current      n           https://lendingclub.com/browse/loanDetail.action?loan_id=137219032  home_improvement    Home improvement         781xx     TX          May-1993          96.6%       w                    Jun-2020      Aug-2020      May-2020            Joint App         Source Verified            Aug-2003                  Y              CVD19SKIP      INCOME_CURTAILMENT  ACTIVE           May-2020             Jul-2020           May-2020                 ACTIVE                N                       1
# 137217341  36 months  14.47%    C      C2         maid                           9 years     MORTGAGE        Not Verified         Jul-2018  Current      n           https://lendingclub.com/browse/loanDetail.action?loan_id=137217341  other               Other                    346xx     FL          Mar-2003          73.3%       f                    Jun-2020      Aug-2020      May-2020            Joint App         Not Verified               Nov-1999                  Y              CVD19SKIP      UNEMPLOYMENT        ACTIVE           May-2020             Jul-2020           May-2020                 GRACE_CURRENT         N                       1
# 137213684  60 months  10.47%    B      B2         Collections                    10+ years   OWN             Verified             Jul-2018  Current      n           https://lendingclub.com/browse/loanDetail.action?loan_id=137213684  debt_consolidation  Debt consolidation       935xx     CA          Oct-2005          4.5%        w                    Jul-2020      Sep-2020      May-2020            Joint App         Verified                   Aug-2009                  Y              CVD19SKIP      INCOME_CURTAILMENT  ACTIVE           May-2020             Aug-2020           Jun-2020                 ACTIVE                N                       1
# 168158403  36 months  18.62%    D      D1         Project Manager                1 year      RENT            Not Verified         Mar-2020  Current      n           https://lendingclub.com/browse/loanDetail.action?loan_id=168158403  debt_consolidation  Debt consolidation       346xx     FL          Nov-2010          44.4%       w                    Jun-2020      Aug-2020      May-2020            Joint App         Not Verified               Dec-2006                  Y              CVD19SKIP      REDCDHOURS          ACTIVE           May-2020             Jul-2020           May-2020                 ACTIVE                N                       1
# Name: count, Length: 8811, dtype: int64

# %%
origin_data["loan_status"].value_counts()
# Out:
# loan_status
# Fully Paid                                             898522
# Current                                                618688
# Charged Off                                            217366
# Late (31-120 days)                                       9840
# In Grace Period                                          6049
# Late (16-30 days)                                        1620
# Issued                                                   1258
# Does not meet the credit policy. Status:Fully Paid       1223
# Does not meet the credit policy. Status:Charged Off       460
# Default                                                   268
# Name: count, dtype: int64

# %%
# target field
# loan_status : target_field인데 이를 어떻게 해결할까요?
# Current, Fully Paid, Charged Off, Issued, ... 등등이 존재함
"""
loan_status
Fully Paid                                             898522 : 채무상환 완료 - 확실한 긍정
Current                                                618688 : 현재 대출이 진행 중인 대출 - 필요한가?
Charged Off                                            217366 : 감가상각에 들어간 대출(채권자가 채무자에게 돈 받기를 포기) - 논의 필요
Late (31-120 days)                                       9840 : 연체 - 부정적? 아니면 그래도 갚았으니 긍정적?
In Grace Period                                          6049 : 유예기간(만료기간이 끝나고, 연체기간이 가기 전) - 부정적?
Late (16-30 days)                                        1620 : 연체 - 부정적? 아니면 그래도 갚았으니 긍정적?
Issued                                                   1258 : ???
Does not meet the credit policy. Status:Fully Paid       1223 : ???
Does not meet the credit policy. Status:Charged Off       460 : ???
Default                                                   268 : 파산 - 확실한 부정
"""
# 제외해도 괜찮을 거같은 field
# id : 의미가 없는 field~
# grade : sub_grade가 해당 값을 포함
# url : 이것도 의미가 없다~

# 전처리해야할 필드
"""suffix 처리"""
# term : xx months -> xx
# int_rate : xx.xx% -> xx.xx
# revol_util : %
# zip_code : 000xx -> 000
"""categorical 값"""  # 이거는 replace 혹은, get_dummies를 사용해서 편집한다. 혹은 astype('category')를 사용하기
# emp_length : 너무 제 각각 이다.
# home_ownership : ['MORTGAGE', 'RENT', 'OWN', 'ANY', 'OTHER', 'NONE', nan]
# verification_status : ['Verified', 'Source Verified', 'Not Verified', nan]
# pymnt_plan : ['n', nan] nan을 drop한다.
# purpose:
"""['debt_consolidation', 'credit_card', 'home_improvement', 'house',
'other', 'vacation', 'car', 'major_purchase', 'small_business',
'medical', 'moving', 'renewable_energy', 'wedding', 'educational',
nan]
"""
# title
# addr_state
# initial_list_status ['w', 'f', nan]
"""날짜 형식"""
# issue_d : %M-%Y (ex) Feb-2010 -> %m-%Y (ex) split해서 year, month?
# earliest_cr_line
# last_pymnt_d
# next_pymnt_d
# last_credit_pull_d
"""
emp_length
['2 years', '10+ years', nan, '5 years', '1 year', '4 years',
'3 years', '< 1 year', '7 years', '6 years', '8 years', '9 years'
"""
"""
loan_status
['Fully Paid', 'Current', 'Charged Off', 'Late (16-30 days)', 'Late (31-120 days)', 'In Grace Period', 'Issued',
'Does not meet the credit policy. Status:Fully Paid',
'Does not meet the credit policy. Status:Charged Off', 'Default',nan]
"""
# 얘기해봐야할 필드
# emp_title : 상위 N개의 직업들만을 갖고갈 것인가?
# Out:
# "\nloan_status\n['Fully Paid', 'Current', 'Charged Off', 'Late (16-30 days)', 'Late (31-120 days)', 'In Grace Period', 'Issued',\n'Does not meet the credit policy. Status:Fully Paid',\n'Does not meet the credit policy. Status:Charged Off', 'Default',nan]\n"

# %%
df_pos= origin_data[origin_data['loan_status'].isin(['Fully Paid', 'Late (16-30 days)', 'Late (31-120 days)'])]
df_pos['loan_status'].tail()
# Out:
# 1755287    Fully Paid
# 1755288    Fully Paid
# 1755291    Fully Paid
# 1755292    Fully Paid
# 1755293    Fully Paid
# Name: loan_status, dtype: object

# %%
df_neg= origin_data[origin_data['loan_status'].isin(['Default'])]
df_neg['loan_status'].head()
# Out:
# 27351    Default
# 29107    Default
# 33301    Default
# 42111    Default
# 42187    Default
# Name: loan_status, dtype: object

# %%
origin_data.shape
# Out:
# (1755295, 141)

# %%
origin_data['loan_status'].value_counts()
# Out:
# loan_status
# Fully Paid                                             898522
# Current                                                618688
# Charged Off                                            217366
# Late (31-120 days)                                       9840
# In Grace Period                                          6049
# Late (16-30 days)                                        1620
# Issued                                                   1258
# Does not meet the credit policy. Status:Fully Paid       1223
# Does not meet the credit policy. Status:Charged Off       460
# Default                                                   268
# Name: count, dtype: int64

# %%
# Current status는 판별에 도움이 되지 않는다.
# 이제부터는 modified_df로 전처리한다.
modified_df = origin_data[origin_data['loan_status']!='Current']
modified_df.shape
# Out:
# (1136607, 141)

# %%
# modified_df(loan_staus!='Current')가 origin_df에서 35.24%가 걸러짐
rows_deleted = ((len(origin_data)-len(modified_df))*100)/len(origin_data)
print(rows_deleted)
# Out:
# 35.24695279141113

# %%
# 중복 제거
duplicate_rows = len(modified_df[modified_df.duplicated()])
print(round(duplicate_rows,2))
# Out:
# 0

# %%
# null로만 채워진 field를 확인한다.
(modified_df.isnull().sum()*100)/len(modified_df)
# Out:
# id                                             0.000000
# loan_amnt                                      0.000088
# funded_amnt                                    0.000088
# funded_amnt_inv                                0.000088
# term                                           0.000088
#                                                 ...
# hardship_loan_status                          99.103648
# orig_projected_additional_accrued_interest    98.292110
# hardship_payoff_balance_amount                98.146853
# hardship_last_payment_amount                  98.146853
# debt_settlement_flag                           0.000088
# Length: 141, dtype: float64

# %%
# modified_df = modified_df.dropna(axis=1, how='all')
# modified_df
# modified_df = modified_df.dropna(axis=0, how='all')
# modified_df

# %%
# 모두가 고유한 값을 가지는 값
unique_columns = [col for col in modified_df.columns if modified_df[col].nunique() == len(modified_df)]
unique_columns
# Out:
# ['id']

# %%
modified_df.select_dtypes('object').value_counts()
# Out:
# id         term       int_rate  grade  sub_grade  emp_title               emp_length  home_ownership  verification_status  issue_d   loan_status         pymnt_plan  url                                                                 purpose             title                    zip_code  addr_state  earliest_cr_line  revol_util  initial_list_status  last_pymnt_d  next_pymnt_d  last_credit_pull_d  application_type  verification_status_joint  sec_app_earliest_cr_line  hardship_flag  hardship_type  hardship_reason  hardship_status  hardship_start_date  hardship_end_date  payment_plan_start_date  hardship_loan_status  debt_settlement_flag
# 101136079  36 months  16.99%    D      D1         Taxi Driver             10+ years   OWN             Verified             Mar-2017  In Grace Period     n           https://lendingclub.com/browse/loanDetail.action?loan_id=101136079  debt_consolidation  Debt consolidation       114xx     NY          Sep-1991          3.2%        w                    Apr-2020      Jun-2020      May-2020            Joint App         Verified                   Aug-2004                  N              CVD19SKIP      INCOMECURT       COMPLETE         Apr-2020             May-2020           Mar-2020                 GRACE_CURRENT         N                       1
# 148538015  36 months   7.56%    A      A3         Service Tech            7 years     MORTGAGE        Verified             Apr-2019  In Grace Period     n           https://lendingclub.com/browse/loanDetail.action?loan_id=148538015  credit_card         Credit card refinancing  606xx     IL          Nov-2000          42.3%       w                    Apr-2020      Jun-2020      May-2020            Joint App         Source Verified            Apr-1996                  N              CVD19SKIP      UNEMPLOYED       COMPLETE         Apr-2020             May-2020           Mar-2020                 GRACE_CURRENT         N                       1
# 149024923  60 months  28.80%    D      D5         Sales Person            5 years     RENT            Verified             Mar-2019  In Grace Period     n           https://lendingclub.com/browse/loanDetail.action?loan_id=149024923  debt_consolidation  Debt consolidation       113xx     NY          Oct-2012          80.3%       w                    Apr-2020      Jun-2020      May-2020            Joint App         Source Verified            Jan-2012                  N              CVD19SKIP      UNEMPLOYED       COMPLETE         Apr-2020             May-2020           Mar-2020                 INCOLLECTION          N                       1
# 148935962  36 months  20.00%    D      D2         Service Advisor         4 years     MORTGAGE        Not Verified         Mar-2019  In Grace Period     n           https://lendingclub.com/browse/loanDetail.action?loan_id=148935962  debt_consolidation  Debt consolidation       068xx     CT          Dec-1997          46.5%       w                    Apr-2020      Jun-2020      May-2020            Joint App         Not Verified               May-2001                  N              CVD19SKIP      INCOMECURT       COMPLETE         Apr-2020             May-2020           Mar-2020                 GRACE_CURRENT         N                       1
# 148919759  36 months  11.71%    B      B3         Finisher lead           < 1 year    RENT            Source Verified      Mar-2019  In Grace Period     n           https://lendingclub.com/browse/loanDetail.action?loan_id=148919759  debt_consolidation  Debt consolidation       928xx     CA          Dec-2011          35.1%       w                    Apr-2020      Jun-2020      May-2020            Joint App         Source Verified            Jun-2011                  N              CVD19SKIP      UNEMPLOYED       COMPLETE         Apr-2020             May-2020           Mar-2020                 GRACE_CURRENT         N                       1
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     ..
# 132697694  36 months  12.61%    C      C1         parts Supervisor        < 1 year    MORTGAGE        Verified             May-2018  Late (31-120 days)  n           https://lendingclub.com/browse/loanDetail.action?loan_id=132697694  debt_consolidation  Debt consolidation       330xx     FL          Feb-2003          62.2%       w                    Feb-2020      Jun-2020      May-2020            Joint App         Source Verified            Feb-2003                  Y              ST0650PV01     REDCDHOURS       ACTIVE           Dec-2019             Mar-2020           Jan-2020                 CURRENT               N                       1
# 132554425  36 months  21.85%    D      D5         teacher                 1 year      RENT            Source Verified      May-2018  Late (31-120 days)  n           https://lendingclub.com/browse/loanDetail.action?loan_id=132554425  other               Other                    104xx     NY          Mar-2010          50.5%       w                    Mar-2020      Jun-2020      May-2020            Joint App         Source Verified            Oct-2011                  Y              ST0650PV01     DISABILITY       ACTIVE           Dec-2019             Mar-2020           Jan-2020                 INCOLLECTION          N                       1
# 132257701  36 months  16.01%    C      C5         Manager (food service)  < 1 year    RENT            Not Verified         May-2018  In Grace Period     n           https://lendingclub.com/browse/loanDetail.action?loan_id=132257701  credit_card         Credit card refinancing  727xx     AR          Feb-2015          34.9%       w                    May-2020      Jul-2020      May-2020            Joint App         Not Verified               Nov-2010                  N              CVD19SKIP      INCOMECURT       COMPLETE         Apr-2020             May-2020           Mar-2020                 ACTIVE                N                       1
# 132197272  36 months  17.47%    D      D1         Truck Driver            4 years     MORTGAGE        Source Verified      Apr-2018  In Grace Period     n           https://lendingclub.com/browse/loanDetail.action?loan_id=132197272  other               Other                    997xx     AK          Sep-2008          38.4%       w                    Apr-2020      Jun-2020      May-2020            Joint App         Source Verified            Mar-2010                  N              CVD19SKIP      REDCDHOURS       COMPLETE         Apr-2020             May-2020           Mar-2020                 GRACE_CURRENT         N                       1
# 168644232  36 months   8.81%    A      A5         Pilot                   10+ years   MORTGAGE        Source Verified      Mar-2020  Issued              n           https://lendingclub.com/browse/loanDetail.action?loan_id=168644232  debt_consolidation  Debt consolidation       605xx     IL          Sep-2008          43.3%       w                    May-2020      Jul-2020      May-2020            Joint App         Source Verified            Sep-2008                  Y              CVD19SKIP      REDCDHOURS       ACTIVE           Apr-2020             Jun-2020           Apr-2020                 ACTIVE                N                       1
# Name: count, Length: 314, dtype: int64

# %%
modified_df['term']
# Out:
# 0           36 months
# 2           60 months
# 5           36 months
# 6           36 months
# 7           36 months
#               ...
# 1755288     60 months
# 1755290     36 months
# 1755291     36 months
# 1755292     36 months
# 1755293     36 months
# Name: term, Length: 1136607, dtype: object

# %%
import datetime as dt
import warnings

warnings.filterwarnings('ignore')

# %%
# term이 NA인 값 삭제
modified_df[modified_df['term'].isna()==True].index
# Out:
# Index([956843], dtype='int64')

# %%
modified_df.drop(modified_df[modified_df['term'].isna()==True].index, inplace=True)

# %%
def delete_suffix(term):
    term = term.strip().split()[0]
    return int(term)
modified_df['term'] = modified_df['term'].astype(str).apply(delete_suffix)
modified_df
# Out:
#                 id  loan_amnt  funded_amnt  funded_amnt_inv  term int_rate  \
# 0        124989905     6000.0       6000.0           6000.0    36    7.97%
# 2         84253847    23200.0      23200.0          23200.0    60   24.99%
# 5        119708428    16000.0      16000.0          16000.0    36    7.07%
# 6        109906493     4500.0       4500.0           4500.0    36   10.42%
# 7         60286250    20000.0      20000.0          20000.0    36    9.99%
# ...            ...        ...          ...              ...   ...      ...
# 1755288    3218223    26500.0      26500.0          26450.0    60   17.27%
# 1755290   12987407     3600.0       3600.0           3600.0    36   19.99%
# 1755291   44299336    19000.0      19000.0          18875.0    36    6.68%
# 1755292    5205034     9600.0       9600.0           9600.0    36   14.33%
# 1755293  128261912    24000.0      24000.0          24000.0    36    7.35%
#
#          installment grade sub_grade             emp_title  ...  \
# 0             187.94     A        A5               Teacher  ...
# 2             680.82     E        E4    Production Foreman  ...
# 5             494.55     A        A2                   NaN  ...
# 6             146.10     B        B3          Team Manager  ...
# 7             645.25     B        B3               teacher  ...
# ...              ...   ...       ...                   ...  ...
# 1755288       662.45     C        C5       Quality Contour  ...
# 1755290       133.78     E        E1              Manager   ...
# 1755291       583.89     A        A3      Systems Engineer  ...
# 1755292       329.65     C        C1  ESS Support services  ...
# 1755293       744.90     A        A4       sales associate  ...
#
#         hardship_start_date hardship_end_date  payment_plan_start_date  \
# 0                       NaN               NaN                      NaN
# 2                       NaN               NaN                      NaN
# 5                       NaN               NaN                      NaN
# 6                       NaN               NaN                      NaN
# 7                       NaN               NaN                      NaN
# ...                     ...               ...                      ...
# 1755288                 NaN               NaN                      NaN
# 1755290                 NaN               NaN                      NaN
# 1755291                 NaN               NaN                      NaN
# 1755292                 NaN               NaN                      NaN
# 1755293                 NaN               NaN                      NaN
#
#         hardship_length hardship_dpd hardship_loan_status  \
# 0                   NaN          NaN                  NaN
# 2                   NaN          NaN                  NaN
# 5                   NaN          NaN                  NaN
# 6                   NaN          NaN                  NaN
# 7                   NaN          NaN                  NaN
# ...                 ...          ...                  ...
# 1755288             NaN          NaN                  NaN
# 1755290             NaN          NaN                  NaN
# 1755291             NaN          NaN                  NaN
# 1755292             NaN          NaN                  NaN
# 1755293             NaN          NaN                  NaN
#
#         orig_projected_additional_accrued_interest  \
# 0                                              NaN
# 2                                              NaN
# 5                                              NaN
# 6                                              NaN
# 7                                              NaN
# ...                                            ...
# 1755288                                        NaN
# 1755290                                        NaN
# 1755291                                        NaN
# 1755292                                        NaN
# 1755293                                        NaN
#
#         hardship_payoff_balance_amount hardship_last_payment_amount  \
# 0                                  NaN                          NaN
# 2                                  NaN                          NaN
# 5                                  NaN                          NaN
# 6                                  NaN                          NaN
# 7                                  NaN                          NaN
# ...                                ...                          ...
# 1755288                            NaN                          NaN
# 1755290                            NaN                          NaN
# 1755291                            NaN                          NaN
# 1755292                            NaN                          NaN
# 1755293                            NaN                          NaN
#
#         debt_settlement_flag
# 0                          N
# 2                          Y
# 5                          N
# 6                          N
# 7                          N
# ...                      ...
# 1755288                    N
# 1755290                    N
# 1755291                    N
# 1755292                    N
# 1755293                    N
#
# [1136606 rows x 141 columns]

# %%
def delete_suffix_percentage(term):
    term = term.strip('%')
    return float(term)
modified_df['int_rate'] = modified_df['int_rate'].astype(str).apply(delete_suffix_percentage)
modified_df['revol_util'] = modified_df['revol_util'].astype(str).apply(delete_suffix_percentage)
modified_df
# Out:
#                 id  loan_amnt  funded_amnt  funded_amnt_inv  term  int_rate  \
# 0        124989905     6000.0       6000.0           6000.0    36      7.97
# 2         84253847    23200.0      23200.0          23200.0    60     24.99
# 5        119708428    16000.0      16000.0          16000.0    36      7.07
# 6        109906493     4500.0       4500.0           4500.0    36     10.42
# 7         60286250    20000.0      20000.0          20000.0    36      9.99
# ...            ...        ...          ...              ...   ...       ...
# 1755288    3218223    26500.0      26500.0          26450.0    60     17.27
# 1755290   12987407     3600.0       3600.0           3600.0    36     19.99
# 1755291   44299336    19000.0      19000.0          18875.0    36      6.68
# 1755292    5205034     9600.0       9600.0           9600.0    36     14.33
# 1755293  128261912    24000.0      24000.0          24000.0    36      7.35
#
#          installment grade sub_grade             emp_title  ...  \
# 0             187.94     A        A5               Teacher  ...
# 2             680.82     E        E4    Production Foreman  ...
# 5             494.55     A        A2                   NaN  ...
# 6             146.10     B        B3          Team Manager  ...
# 7             645.25     B        B3               teacher  ...
# ...              ...   ...       ...                   ...  ...
# 1755288       662.45     C        C5       Quality Contour  ...
# 1755290       133.78     E        E1              Manager   ...
# 1755291       583.89     A        A3      Systems Engineer  ...
# 1755292       329.65     C        C1  ESS Support services  ...
# 1755293       744.90     A        A4       sales associate  ...
#
#         hardship_start_date hardship_end_date  payment_plan_start_date  \
# 0                       NaN               NaN                      NaN
# 2                       NaN               NaN                      NaN
# 5                       NaN               NaN                      NaN
# 6                       NaN               NaN                      NaN
# 7                       NaN               NaN                      NaN
# ...                     ...               ...                      ...
# 1755288                 NaN               NaN                      NaN
# 1755290                 NaN               NaN                      NaN
# 1755291                 NaN               NaN                      NaN
# 1755292                 NaN               NaN                      NaN
# 1755293                 NaN               NaN                      NaN
#
#         hardship_length hardship_dpd hardship_loan_status  \
# 0                   NaN          NaN                  NaN
# 2                   NaN          NaN                  NaN
# 5                   NaN          NaN                  NaN
# 6                   NaN          NaN                  NaN
# 7                   NaN          NaN                  NaN
# ...                 ...          ...                  ...
# 1755288             NaN          NaN                  NaN
# 1755290             NaN          NaN                  NaN
# 1755291             NaN          NaN                  NaN
# 1755292             NaN          NaN                  NaN
# 1755293             NaN          NaN                  NaN
#
#         orig_projected_additional_accrued_interest  \
# 0                                              NaN
# 2                                              NaN
# 5                                              NaN
# 6                                              NaN
# 7                                              NaN
# ...                                            ...
# 1755288                                        NaN
# 1755290                                        NaN
# 1755291                                        NaN
# 1755292                                        NaN
# 1755293                                        NaN
#
#         hardship_payoff_balance_amount hardship_last_payment_amount  \
# 0                                  NaN                          NaN
# 2                                  NaN                          NaN
# 5                                  NaN                          NaN
# 6                                  NaN                          NaN
# 7                                  NaN                          NaN
# ...                                ...                          ...
# 1755288                            NaN                          NaN
# 1755290                            NaN                          NaN
# 1755291                            NaN                          NaN
# 1755292                            NaN                          NaN
# 1755293                            NaN                          NaN
#
#         debt_settlement_flag
# 0                          N
# 2                          Y
# 5                          N
# 6                          N
# 7                          N
# ...                      ...
# 1755288                    N
# 1755290                    N
# 1755291                    N
# 1755292                    N
# 1755293                    N
#
# [1136606 rows x 141 columns]

# %%
modified_df['earliest_cr_line']=pd.to_datetime(modified_df['earliest_cr_line'], format='%b-%y')
modified_df['earliest_cr_line'].head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 modified_df['earliest_cr_line']=pd.to_datetime(modified_df.earliest_cr_line, format='%b-%y')
#       2 modified_df['earliest_cr_line'].head()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\tools\datetimes.py:1063, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1061             result = arg.tz_localize("utc")
#    1062 elif isinstance(arg, ABCSeries):
# -> 1063     cache_array = _maybe_cache(arg, format, cache, convert_listlike)
#    1064     if not cache_array.empty:
#    1065         result = arg.map(cache_array)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\tools\datetimes.py:247, in _maybe_cache(arg, format, cache, convert_listlike)
#     245 unique_dates = unique(arg)
#     246 if len(unique_dates) < len(arg):
# --> 247     cache_dates = convert_listlike(unique_dates, format)
#     248     # GH#45319
#     249     try:
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\tools\datetimes.py:433, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     431 # `format` could be inferred, or user didn't ask for mixed-format parsing.
#     432 if format is not None and format != "mixed":
# --> 433     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
#     435 result, tz_parsed = objects_to_datetime64(
#     436     arg,
#     437     dayfirst=dayfirst,
#    (...)
#     441     allow_object=True,
#     442 )
#     444 if tz_parsed is not None:
#     445     # We can take a shortcut since the datetime64 numpy array
#     446     # is in UTC
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\tools\datetimes.py:467, in _array_strptime_with_fallback(arg, name, utc, fmt, exact, errors)
#     456 def _array_strptime_with_fallback(
#     457     arg,
#     458     name,
#    (...)
#     462     errors: str,
#     463 ) -> Index:
#     464     """
#     465     Call array_strptime, with fallback behavior depending on 'errors'.
#     466     """
# --> 467     result, tz_out = array_strptime(arg, fmt, exact=exact, errors=errors, utc=utc)
#     468     if tz_out is not None:
#     469         unit = np.datetime_data(result.dtype)[0]
#
# File strptime.pyx:501, in pandas._libs.tslibs.strptime.array_strptime()
#
# File strptime.pyx:451, in pandas._libs.tslibs.strptime.array_strptime()
#
# File strptime.pyx:587, in pandas._libs.tslibs.strptime._parse_with_format()
#
# ValueError: unconverted data remains when parsing with format "%b-%y": "05", at position 0. You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.

# %%
# 뭔가 에러뜸...
def apply_to_multiple_columns(df, columns, func):
    for col in columns:
        df[col] = df[col].apply(func)
def convert_to_datetime(date):
    return pd.to_datetime(date, format='%b-%y')
columns_to_modify = ['earliest_cr_line','last_pymnt_d','next_pymnt_d',
                     'last_credit_pull_d','sec_app_earliest_cr_line',
                     'hardship_start_date','hardship_end_date',
                     'payment_plan_start_date']
apply_to_multiple_columns(modified_df, columns_to_modify, convert_to_datetime)
modified_df['earliest_cr_line'].head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[50], line 11
#       6     return pd.to_datetime(date, format='%b-%y')
#       7 columns_to_modify = ['earliest_cr_line','last_pymnt_d','next_pymnt_d',
#       8                      'last_credit_pull_d','sec_app_earliest_cr_line',
#       9                      'hardship_start_date','hardship_end_date',
#      10                      'payment_plan_start_date']
# ---> 11 apply_to_multiple_columns(modified_df, columns_to_modify, convert_to_datetime)
#      12 modified_df['earliest_cr_line'].head()
#
# Cell In[50], line 4, in apply_to_multiple_columns(df, columns, func)
#       2 def apply_to_multiple_columns(df, columns, func):
#       3     for col in columns:
# ----> 4         df[col] = df[col].apply(func)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\series.py:4904, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4769 def apply(
#    4770     self,
#    4771     func: AggFuncType,
#    (...)
#    4776     **kwargs,
#    4777 ) -> DataFrame | Series:
#    4778     """
#    4779     Invoke function on values of Series.
#    4780
#    (...)
#    4895     dtype: float64
#    4896     """
#    4897     return SeriesApply(
#    4898         self,
#    4899         func,
#    4900         convert_dtype=convert_dtype,
#    4901         by_row=by_row,
#    4902         args=args,
#    4903         kwargs=kwargs,
# -> 4904     ).apply()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[50], line 6, in convert_to_datetime(date)
#       5 def convert_to_datetime(date):
# ----> 6     return pd.to_datetime(date, format='%b-%y')
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\tools\datetimes.py:1101, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1099         result = convert_listlike(argc, format)
#    1100 else:
# -> 1101     result = convert_listlike(np.array([arg]), format)[0]
#    1102     if isinstance(arg, bool) and isinstance(result, np.bool_):
#    1103         result = bool(result)  # TODO: avoid this kludge.
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\tools\datetimes.py:433, in _convert_listlike_datetimes(arg, format, name, utc, unit, errors, dayfirst, yearfirst, exact)
#     431 # `format` could be inferred, or user didn't ask for mixed-format parsing.
#     432 if format is not None and format != "mixed":
# --> 433     return _array_strptime_with_fallback(arg, name, utc, format, exact, errors)
#     435 result, tz_parsed = objects_to_datetime64(
#     436     arg,
#     437     dayfirst=dayfirst,
#    (...)
#     441     allow_object=True,
#     442 )
#     444 if tz_parsed is not None:
#     445     # We can take a shortcut since the datetime64 numpy array
#     446     # is in UTC
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\tools\datetimes.py:467, in _array_strptime_with_fallback(arg, name, utc, fmt, exact, errors)
#     456 def _array_strptime_with_fallback(
#     457     arg,
#     458     name,
#    (...)
#     462     errors: str,
#     463 ) -> Index:
#     464     """
#     465     Call array_strptime, with fallback behavior depending on 'errors'.
#     466     """
# --> 467     result, tz_out = array_strptime(arg, fmt, exact=exact, errors=errors, utc=utc)
#     468     if tz_out is not None:
#     469         unit = np.datetime_data(result.dtype)[0]
#
# File strptime.pyx:501, in pandas._libs.tslibs.strptime.array_strptime()
#
# File strptime.pyx:451, in pandas._libs.tslibs.strptime.array_strptime()
#
# File strptime.pyx:587, in pandas._libs.tslibs.strptime._parse_with_format()
#
# ValueError: unconverted data remains when parsing with format "%b-%y": "05", at position 0. You might want to try:
#     - passing `format` if your strings have a consistent format;
#     - passing `format='ISO8601'` if your strings are all ISO8601 but not necessarily in exactly the same format;
#     - passing `format='mixed'`, and the format will be inferred for each element individually. You might want to use `dayfirst` alongside this.
