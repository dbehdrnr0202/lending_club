# %%
import pandas as pd
import numpy as np

# %%
origin_data = pd.read_csv("data/lending_club_2020_train.csv")
origin_data.head()
# Out:
# C:\Users\Hi\AppData\Local\Temp\ipykernel_29360\1849447870.py:1: DtypeWarning: Columns (0) have mixed types. Specify dtype option on import or set low_memory=False.
#   origin_data = pd.read_csv("data/lending_club_2020_train.csv")
#           id  loan_amnt  funded_amnt  funded_amnt_inv        term int_rate  \
# 0  124989905     6000.0       6000.0           6000.0   36 months    7.97%
# 1  139665484    35000.0      35000.0          35000.0   60 months   14.47%
# 2   84253847    23200.0      23200.0          23200.0   60 months   24.99%
# 3  126296074     4500.0       4500.0           4500.0   36 months    9.93%
# 4  148913312    15000.0      15000.0          15000.0   36 months   16.40%
#
#    installment grade sub_grade           emp_title  ... hardship_start_date  \
# 0       187.94     A        A5             Teacher  ...                 NaN
# 1       822.95     C        C2  Product Specialist  ...                 NaN
# ...

# %%
lst = []
with open("find_list.txt", mode='r') as f:
    while 1:
        line = f.readline().strip('\n')
        if not line: break
        lst.append(line)
print(len(lst), lst)
# Out:
# 18 ['deferral_term', 'hardship_amount', 'hardship_start_date', 'hardship_end_date', 'payment_plan_start_date', 'hardship_length', 'hardship_dpd', 'hardship_loan_status', 'orig_projected_additional_accrued_interest', 'hardship_payoff_balance_amount', 'hardship_last_payment_amount', 'debt_settlement_flag', 'debt_settlement_flag_date', 'settlement_status', 'settlement_date', 'settlement_amount', 'settlement_percentage', 'settlement_term']

# %%
fields = origin_data.columns

# %%
def check_fields(lst):
    for index, field in enumerate(lst):
        try:
            origin_data[field]
            print(f"=========================================={index, field}==========")
            print("======value_count======")
            print(origin_data[field].value_counts())
            print("======Null percentage======")
            print((origin_data[field].isnull().sum()*100)/len(origin_data))
            print("======NaN percentage======")
            print((origin_data[field].isna().sum()*100)/len(origin_data))
            print("======data head======")
            print(origin_data[field].head())
        except KeyError as ke:
            print(ke, field)

# %%
check_fields(lst)
# Out:
# ==========================================(0, 'deferral_term')==========
# ======value_count======
# deferral_term
# 2.0    71958
# 3.0     7925
# 4.0     6146
# 0.0        7
# Name: count, dtype: int64
# ======Null percentage======
# 95.09848771858861
# ======NaN percentage======
# 95.09848771858861
# ======data head======
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    2.0
# Name: deferral_term, dtype: float64
# ==========================================(1, 'hardship_amount')==========
# ======value_count======
# hardship_amount
# 0.00       78242
# 1225.24       61
# 317.12        50
# 360.23        48
# 306.31        42
#            ...
# 290.18         1
# 523.09         1
# 126.17         1
# 1089.03        1
# 390.32         1
# Name: count, Length: 15576, dtype: int64
# ======Null percentage======
# 93.78275446577356
# ======NaN percentage======
# 93.78275446577356
# ======data head======
# 0    NaN
# 1    NaN
# 2    NaN
# 3    NaN
# 4    0.0
# ...

# %%
field = "settlement_amount"
print(origin_data[field].min())
print(origin_data[field].max())
print(origin_data[field].unique())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python311\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File index.pyx:153, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:182, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'settlement_amount'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[57], line 2
#       1 field = "settlement_amount"
# ...
